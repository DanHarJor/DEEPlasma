# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Using JET 97781 and GENE to get parameter ranges

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from config import Config
config = Config()
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
parser = GENE_scan_parser(config)
# save_dir = '/home/djdaniel/DEEPlasma/vault/data_gen_tutorial7'
save_dir='/scratch/project_462000451/gene_out/gene_auto_97781/omt_range/'
dataset_x0 = ScanData2(name='jet_97781_ion-scale', config=config, parser=parser, save_dir=save_dir,  split_ratio=[0,0,1], categorise=True, group_var_list=[('_grp_species_0','omn'),('_grp_species_0','omt'),('_grp_species_0','omt'),('_grp_species_1','temp'),('units','Tref'),('units','nref'),('units','Bref')])
# Out:
# /LUMI_TYKKY_A4hLOAk/miniconda/envs/env1/lib/python3.12/site-packages/paramiko/pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /LUMI_TYKKY_A4hLOAk/miniconda/envs/env1/lib/python3.12/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# /LUMI_TYKKY_A4hLOAk/miniconda/envs/env1/lib/python3.12/site-packages/paramiko/transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# Initialising dataset
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 10
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 11
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 12
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 13
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 14
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 15
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 16
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 17
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 18
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 19
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 20
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 21
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 22
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 23
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 24
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 25
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 26
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 27
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 28
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 29
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 30
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 31
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 32
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 33
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 34
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 35
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 36
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 37
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 38
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 39
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 40
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 41
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 42
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 43
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 44
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 45
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 46
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 47
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 48
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 49
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 50
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 51
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 52
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 53
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 54
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 55
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 56
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 57
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 58
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 59
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 60
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 61
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 62
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 63
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 64
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 65
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 66
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 67
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 68
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 69
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 70
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 71
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 72
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 73
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 74
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 75
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 76
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 77
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 78
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 79
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 80
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 81
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 82
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 83
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 84
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 85
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 86
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 87
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 88
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 89
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 90
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 91
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 92
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 93
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 94
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 95
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 96
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 97
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 98
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 99
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 100
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 101
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 102
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 103
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 104
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 105
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 106
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 107
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 108
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 109
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 110
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 111
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 112
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 113
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 114
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 115
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 116
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 117
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 118
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 119
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 120
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 121
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 122
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 123
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 124
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 125
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 126
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 127
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 128
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 129
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 130
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 131
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 132
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 133
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 134
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 135
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 136
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 137
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 138
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 139
# There have been 140 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# REASONS FOR GENE STOPPING DETECTED []
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0025
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0026
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0027
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0028
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0029
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0030
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0031
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0032
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0033
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0034
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0035
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0036
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0037
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0038
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0039
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0040
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0041
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0042
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0043
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0044
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0045
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0046
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0047
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0048
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0049
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0050
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0051
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0052
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0053
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0054
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0055
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0056
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0057
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0058
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0059
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0060
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0061
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0062
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0063
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0064
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0065
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0066
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0067
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0068
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0069
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0070
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0071
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0072
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0073
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0074
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0075
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0076
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0077
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0078
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0079
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0080
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0081
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0082
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0083
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0084
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0085
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0086
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0087
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0088
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0089
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0090
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0091
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0092
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0093
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0094
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0095
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0096
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0097
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0098
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0099
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0100
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0101
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0102
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0103
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0104
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0105
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0106
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0107
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0108
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0109
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0110
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0111
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0112
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0113
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0114
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0115
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0116
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0117
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0118
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0119
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0120
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0121
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0122
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0123
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0124
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0125
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0126
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0127
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0128
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0129
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0130
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0131
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0132
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0133
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0134
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0135
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0136
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0137
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0138
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0139
# /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0140
# DEBUG inst ['None'] []
# DEBUG inst ['None'] ['None']
# DEBUG inst ['None'] ['None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# DEBUG inst ['None'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# ...
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0008
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0009
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0010
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0011
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0012
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0013
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0014
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0015
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0016
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0017
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0018
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0019
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0020
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0021
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0022
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0023
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0024
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0025
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0026
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0027
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0028
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0029
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0030
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0031
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0032
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0033
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0034
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0035
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0036
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0037
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0038
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0039
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0040
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0041
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0042
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0043
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0044
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0045
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0046
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0047
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0048
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0049
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0050
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0051
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0052
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0053
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0054
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0055
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0056
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0057
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0058
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0059
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0060
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0061
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0062
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0063
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0064
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0065
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0066
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0067
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0068
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0069
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0070
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0071
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0072
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0073
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0074
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0075
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0076
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0077
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0078
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0079
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0080
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0081
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0082
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0083
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0084
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0085
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0086
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0087
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0088
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0089
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0090
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0091
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0092
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0093
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0094
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0095
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0096
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0097
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0098
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0099
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0100
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0101
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0102
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0103
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0104
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0105
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0106
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0107
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0108
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0109
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0110
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0111
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0112
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0113
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0114
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0115
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0116
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0117
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0118
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0119
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0120
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0121
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0122
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0123
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0124
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0125
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0126
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0127
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0128
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0129
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0130
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0131
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0132
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0133
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0134
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0135
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0136
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0137
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0138
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0139
# gpv, paramater path /scratch/project_462000451/gene_out/gene_auto_97781/omt_range/batch_0/scanfiles0001/parameters_0140
# SETTING VARIABLES
# End of SCAN DATA init

# %%
dataset_x0.df
# Out:
#        x01 growthrate frequency  \
# 0    0.860        NaN       NaN
# 1    0.861        NaN       NaN
# 2    0.862        NaN       NaN
# 3    0.863        NaN       NaN
# 4    0.864        NaN       NaN
# ..     ...        ...       ...
# 135  0.995        NaN       NaN
# 136  0.996        NaN       NaN
# 137  0.997        NaN       NaN
# 138  0.998        NaN       NaN
# 139  0.999        NaN       NaN
#
#                                         scanfiles_path suffix run_time  \
# 0    /scratch/project_462000451/gene_out/gene_auto_...   0001   10.276
# 1    /scratch/project_462000451/gene_out/gene_auto_...   0002   29.873
# 2    /scratch/project_462000451/gene_out/gene_auto_...   0003   14.852
# 3    /scratch/project_462000451/gene_out/gene_auto_...   0004   30.801
# 4    /scratch/project_462000451/gene_out/gene_auto_...   0005   29.621
# ..                                                 ...    ...      ...
# 135  /scratch/project_462000451/gene_out/gene_auto_...   0136   82.409
# 136  /scratch/project_462000451/gene_out/gene_auto_...   0137   37.314
# 137  /scratch/project_462000451/gene_out/gene_auto_...   0138   39.831
# 138  /scratch/project_462000451/gene_out/gene_auto_...   0139   42.137
# 139  /scratch/project_462000451/gene_out/gene_auto_...   0140  105.084
#
#     termination_reason fingerprint fingerprint_string  ratio_iheat_eheat  ...  \
# 0                  NaN      [None]               None           1.196378  ...
# 1                  NaN      [None]               None           1.184840  ...
# 2                  NaN      [None]               None           1.186598  ...
# 3                  NaN      [None]               None           1.190638  ...
# 4                  NaN      [None]               None           1.226413  ...
# ..                 ...         ...                ...                ...  ...
# 135                NaN      [None]               None           3.850680  ...
# 136                NaN      [None]               None           4.032378  ...
# 137                NaN      [None]               None           4.091048  ...
# 138                NaN      [None]               None           4.403588  ...
# 139                NaN      [None]               None           4.477495  ...
#
#      heat_electromagnetic_Ions categorisation  avg_kperp_squared  \
# 0                 9.177100e-37        Nothing          76.369972
# 1                 2.201300e-37        Nothing          76.840908
# 2                 1.231000e-36        Nothing          77.396964
# 3                -1.791000e-36        Nothing          77.925666
# 4                -4.840500e-37        Nothing          78.478013
# ..                         ...            ...                ...
# 135               7.337900e-36        Nothing        1630.494291
# 136               2.008400e-36        Nothing        1887.986829
# 137               4.725400e-36        Nothing        2203.020585
# 138               1.473300e-35        Nothing        2378.168683
# 139               1.715100e-36        Nothing        2277.710768
#
#      mixing_length  _grp_species_0-omn  _grp_species_0-omt  \
# 0              NaN            0.561577            2.868249
# 1              NaN            0.559685            2.874185
# 2              NaN            0.557835            2.880725
# 3              NaN            0.556021            2.887958
# 4              NaN            0.554245            2.895063
# ..             ...                 ...                 ...
# 135            NaN           21.736817           60.001203
# 136            NaN           21.961016           59.961149
# 137            NaN           22.141786           59.780779
# 138            NaN           22.325851           59.631401
# 139            NaN           22.479258           59.380596
#
#      _grp_species_1-temp  units-Tref  units-nref  units-Bref
# 0               1.411887    1.693797    4.122729    3.281048
# 1               1.412535    1.688941    4.120419    3.281048
# 2               1.413186    1.684088    4.118117    3.281048
# 3               1.413841    1.679238    4.115824    3.281048
# 4               1.414499    1.674389    4.113540    3.281048
# ..                   ...         ...         ...         ...
# 135             4.398323    0.133467    1.945354    3.281048
# 136             4.599728    0.125696    1.903311    3.281048
# 137             4.813234    0.118389    1.861786    3.281048
# 138             5.039299    0.111526    1.820832    3.281048
# 139             5.278292    0.105085    1.780503    3.281048
#
# [140 rows x 37 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

x0 = dataset_x0.df['x01'].to_numpy().astype('float')
real_density = dataset_x0.df['units-nref'].to_numpy().astype('float')
real_temp = dataset_x0.df['units-Tref'].to_numpy().astype('float')

fig, ax = plt.subplots()
axt = ax.twinx()
ax.plot(x0, real_density,label='ne x10^-19')
ax.set_ylabel('ne x10^-19')
ax.plot(x0, real_temp, label='T keV', color = 'orange')
# ax.set_ylabel('T keV')
lines1, labels1 = ax.get_legend_handles_labels()
lines2, labels2 = axt.get_legend_handles_labels()
ax.legend(lines1 + lines2, labels1 + labels2, loc='upper right')
ax.vlines((0.90,0.98), 0, 4.1, color='red')
# axt.vlines((0.90,0.98), 0, 4.1, color='red')
axt.plot(x0, real_density/real_temp, '--', color = 'black', label='ne/Te, (right axis)')
axt.legend()


fig, ax = plt.subplots()
axt = ax.twinx()
ne_grad = np.gradient(real_density, x0)
temp_grad = np.gradient(real_temp, x0)

ax.plot(x0, ne_grad)
ax.plot(x0, temp_grad)
ax.vlines((0.90,0.98), 0, -45, color='red')
axt.plot(x0, ne_grad/temp_grad, '--', color = 'black', label='ne_grad / Te_grad (right axis)')
axt.legend()

# %% [markdown]
# # Submitting Runs

# %%
import sys
import os
pathap = os.path.join('GENE_ML','gene_ml','static_sparse_grid_approximations')
print('PATHAP',pathap)
sys.path.append(pathap)

from GENE_ML.gene_ml.samplers.grid import Grid
from GENE_ML.gene_ml.datagen.datagen import DataGen
from GENE_ML.gene_ml.converters.Tratio import Tratio
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config

config = Config(local=True)
parser = GENE_scan_parser(config)

#sampled_parameters = ['box-kymin', 'units-bref', 'units-nref', 'units-tref', 'nongene-Ti/Te', '_grp_species_1-omt', 'geometry-q0', 'species-omn'] #Geometry, Solver, x0,
#bounds = [(0.05,1), (2,4), (0.0001,10), (0.0001,4), (0.5,1.75), (10,70), (3,6), (5,60)]
ky = ['box-kymin']
bounds = [(0.05,2)]
num_samples = 100
sampler = Grid(parameters=ky, num_samples=num_samples, bounds=bounds)


remote_save_name = "jet_97781_ion-scale_90"
ex_id = "jet_97781_ion-scale_90"
num_workers = 8
single_run_timelim = 1000
single_run_simtimelim = 1000
ky_datagen = DataGen(config, sampler, remote_save_name=remote_save_name, ex_id=ex_id, single_run_timelim=single_run_timelim, single_run_simtimelim=single_run_simtimelim, num_workers=num_workers)
# Out:
# PATHAP GENE_ML/gene_ml/static_sparse_grid_approximations

# %%
ky_datagen.executor.pre_run_check()
# Out:
# EXECUTOR, PRINT_CHECK_PARAMETERS
#  ----------------------------------------------------------------------------------------------------
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 13
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-0 is 00-03:58:20, dd-hh-mm-ss TO RUN 13 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-0/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-0/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 0.05, 0.0696969696969697, 0.08939393939393939, 0.10909090909090909, 0.12878787878787878, 0.1484848484848485, 0.16818181818181815, 0.18787878787878787, 0.20757575757575758, 0.22727272727272724, 0.24696969696969695, 0.26666666666666666, 0.2863636363636363
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-0'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:58:20  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x

# %%
ky_datagen.executor.start_runs()
# Out:
# ====================================================================================================
# EXECUTING BATCHES
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 13
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-0 is 00-03:58:20, dd-hh-mm-ss TO RUN 13 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-0/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-0/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 0.05, 0.0696969696969697, 0.08939393939393939, 0.10909090909090909, 0.12878787878787878, 0.1484848484848485, 0.16818181818181815, 0.18787878787878787, 0.20757575757575758, 0.22727272727272724, 0.24696969696969695, 0.26666666666666666, 0.2863636363636363
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-0'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:58:20  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-0
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134189
#  ERROR?:
# OUT: Submitted batch job 9134189
#  ERROR?:
# SUBMITTED SBATCH ID: 9134189
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 13
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-1 is 00-03:58:20, dd-hh-mm-ss TO RUN 13 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-1/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-1/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 0.30606060606060603, 0.32575757575757575, 0.3454545454545454, 0.3651515151515151, 0.38484848484848483, 0.4045454545454545, 0.4242424242424242, 0.4439393939393939, 0.46363636363636357, 0.4833333333333333, 0.503030303030303, 0.5227272727272727, 0.5424242424242424
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-1'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:58:20  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-1
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134190
#  ERROR?:
# OUT: Submitted batch job 9134190
#  ERROR?:
# SUBMITTED SBATCH ID: 9134190
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 13
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-2 is 00-03:58:20, dd-hh-mm-ss TO RUN 13 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-2/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-2/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 0.5621212121212121, 0.5818181818181818, 0.6015151515151516, 0.6212121212121212, 0.6409090909090909, 0.6606060606060606, 0.6803030303030303, 0.7, 0.7196969696969697, 0.7393939393939394, 0.759090909090909, 0.7787878787878788, 0.7984848484848485
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-2'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:58:20  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-2
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134191
#  ERROR?:
# OUT: Submitted batch job 9134191
#  ERROR?:
# SUBMITTED SBATCH ID: 9134191
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 13
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-3 is 00-03:58:20, dd-hh-mm-ss TO RUN 13 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-3/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-3/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 0.8181818181818181, 0.8378787878787879, 0.8575757575757575, 0.8772727272727272, 0.896969696969697, 0.9166666666666666, 0.9363636363636363, 0.956060606060606, 0.9757575757575757, 0.9954545454545454, 1.0151515151515151, 1.0348484848484847, 1.0545454545454545
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-3'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:58:20  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-3
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134192
#  ERROR?:
# OUT: Submitted batch job 9134192
#  ERROR?:
# SUBMITTED SBATCH ID: 9134192
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 12
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-4 is 00-03:40:00, dd-hh-mm-ss TO RUN 12 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-4/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-4/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 1.0742424242424242, 1.093939393939394, 1.1136363636363635, 1.1333333333333333, 1.153030303030303, 1.1727272727272726, 1.1924242424242424, 1.2121212121212122, 1.2318181818181817, 1.2515151515151515, 1.2712121212121212, 1.2909090909090908
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-4'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:40:00  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-4
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134193
#  ERROR?:
# OUT: Submitted batch job 9134193
#  ERROR?:
# SUBMITTED SBATCH ID: 9134193
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 12
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-5 is 00-03:40:00, dd-hh-mm-ss TO RUN 12 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-5/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-5/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 1.3106060606060606, 1.3303030303030303, 1.3499999999999999, 1.3696969696969696, 1.3893939393939394, 1.409090909090909, 1.4287878787878787, 1.4484848484848485, 1.468181818181818, 1.4878787878787878, 1.5075757575757576, 1.5272727272727271
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-5'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:40:00  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-5
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134194
#  ERROR?:
# OUT: Submitted batch job 9134194
#  ERROR?:
# SUBMITTED SBATCH ID: 9134194
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 12
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-6 is 00-03:40:00, dd-hh-mm-ss TO RUN 12 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-6/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-6/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 1.5469696969696969, 1.5666666666666667, 1.5863636363636362, 1.606060606060606, 1.6257575757575757, 1.6454545454545453, 1.665151515151515, 1.6848484848484848, 1.7045454545454544, 1.7242424242424241, 1.743939393939394, 1.7636363636363634
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-6'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:40:00  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-6
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134195
#  ERROR?:
# OUT: Submitted batch job 9134195
#  ERROR?:
# SUBMITTED SBATCH ID: 9134195
# PRE RUN CHECK
#
#
# SINGLE RUN TIMELIM 1000 N SAMPLES 12
# THE ESTIMATED WALLTIME FOR RUN ex-jet_97781_ion-scale_90_batch-7 is 00-03:40:00, dd-hh-mm-ss TO RUN 12 SAMPLES
# CHECKING IF PROBLEM DIRECTORY EXISTS
# PROBLEM DIRECTORY EXISTS
# SBATCH
# WRITE SBATCH
# PARSING SAMPLES TO INPUT FILE at: /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-7/parameters
# Writing to /project/project_462000451/gene/auto_prob_ex-jet_97781_ion-scale_90_batch-7/parameters
# ALTERING THE PARAMETERS FILE IN THE REMOTE PROBLEM DIRECTORY
# 50 timelim 1000
#     timelim = 7200
#
#     timelim = 1000
#
#
#
# CODE RUN: SETTING SIMULATION TIME LIMMIT
#
#
# 51 simtimelim 1000
#     simtimelim = 7200
#
#     simtimelim = 1000
#
# PARAMETERS IN RUN DIR:
# 0: &parallelization
#
# 1:     n_parallel_sims = 1
#
# 2:     n_procs_sim = 128
#
# 3:     n_procs_s = -1
#
# 4:     n_procs_z = -1
#
# 5:     n_procs_w = -1
#
# 6:     min_npw = -1
#
# 7:     max_npw = -1
#
# 8:     n_procs_v = -1
#
# 9:     n_procs_x = -1
#
# 10:     n_procs_y = -1
#
# 11: /
#
# 12:
#
# 13: &box
#
# 14:     n_spec = 2
#
# 15:     nx0 = 18
#
# 16:     nky0 = 1
#
# 17:     nz0 = 36
#
# 18:     nv0 = 32
#
# 19:     nw0 = 16
#
# 20:     kymin = 0.1      !scanlist: 1.7833333333333332, 1.803030303030303, 1.8227272727272725, 1.8424242424242423, 1.862121212121212, 1.8818181818181816, 1.9015151515151514, 1.9212121212121211, 1.9409090909090907, 1.9606060606060605, 1.9803030303030302, 2.0
#
# 21:     lv = 3.1
#
# 22:     lw = 11
#
# 23:     x0 = 0.9
#
# 24:     kx_center = 0.0
#
# 25:     adapt_ly = .true.
#
# 26: /
#
# 27:
#
# 28: &in_out
#
# 29:     diagdir = '/scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-7'
#
# 30:     read_checkpoint = .false.
#
# 31:     istep_nrg = 100
#
# 32:     istep_field = 100
#
# 33:     istep_mom = 2000
#
# 34:     istep_energy = 100
#
# 35:     istep_omega = 10
#
# 36:     istep_vsp = 5000
#
# 37:     istep_schpt = 5000
#
# 38:     istep_srcmom = 2000
#
# 39:     iterdb_file = '/project/project_462000451/jet_97781_data/iterdb_jet_97781'
#
# 40: /
#
# 41:
#
# 42: &general
#
# 43:     nblocks = 16
#
# 44:     f_version = .false.
#
# 45:     nonlinear = .false.
#
# 46:     x_local = .true.
#
# 47:     arakawa_zv = .false.
#
# 48:     comp_type = 'IV'
#
# 49:     calc_dt = .true.
#
# 50:     timelim = 1000
#
# 51:     simtimelim = 1000
#
# 52:     underflow_limit = 1e-15
#
# 53:     collision_op = 'landau'
#
# 54:     coll_cons_model = 'self_adj'
#
# 55:     coll = -1
#
# 56:     zeff = 1
#
# 57:     beta = -1
#
# 58:     debye2 = -1
#
# 59:     hyp_z = -1
#
# 60:     init_cond = 'ppjrn'
#
# 61: /
#
# 62:
#
# 63: &geometry
#
# 64:     edge_opt = 1.0
#
# 65:     magn_geometry = 'tracer_efit'
#
# 66:     geomdir = ''
#
# 67:     geomfile = '/project/project_462000451/jet_97781_data/jet97781.eqdsk'
#
# 68:     rhostar = -1
#
# 69:     mag_prof = .true.
#
# 70:     sign_ip_cw = 1
#
# 71:     sign_bt_cw = 1
#
# 72: /
#
# 73:
#
# 74: &species
#
# 75:     name = 'Electrons'
#
# 76:     mass = 0.0002725
#
# 77:     charge = -1
#
# 78:     prof_type = -2
#
# 79: /
#
# 80:
#
# 81: &species
#
# 82:     name = 'Ions'
#
# 83:     mass = 1.0
#
# 84:     charge = 1
#
# 85:     prof_type = -2
#
# 86: /
#
# 87:
#
# 88: &units
#
# 89:     tref = -1
#
# 90:     nref = -1
#
# 91:     bref = -1
#
# 92:     lref = -1
#
# 93:     mref = 2
#
# 94:     omegatorref = -1
#
# 95: /
# SBATCH IN RUN DIR:
# 0: #!/bin/bash -l
#
# 1: ## LUMI-C (CPU partition) submit script template
#
# 2: ## Submit via: sbatch submit.cmd (parameters below can be overwritten by command line options)
#
# 3: #SBATCH -t 00-03:40:00  ## wallclock limit, dd-hh:mm:ss
#
# 4: #SBATCH -N 1                       # total number of nodes, 2 CPUs with 64 rank each
#
# 5: #SBATCH --ntasks=128      # 64 per CPU (i.e. 128 per node). Additional 2 hyperthreads disabled
#
# 6: #SBATCH --mem=0                    # Allocate all the memory on each node
#
# 7: #SBATCH -p standard                # all options see: scontrol show partition
#
# 8: #SBATCH -J auto_gene                    # Job name
#
# 9: #SBATCH -o ./%x.%j.out
#
# 10: #SBATCH -e ./%x.%j.err
#
# 11: ##uncomment to set specific account to charge or define SBATCH_ACCOUNT/SALLOC_ACCOUNT globally in ~/.bashrc
#
# 12: #SBATCH -A project_462000451
#
# 13:
#
# 14: export MEMORY_PER_CORE=1800
#
# 15:
#
# 16: ## set openmp threads
#
# 17: export OMP_NUM_THREADS=1
#
# 18:
#
# 19: #do not use file locking for hdf5
#
# 20: export HDF5_USE_FILE_LOCKING=FALSE
#
# 21:
#
# 22: set -x
#
# 23: # run GENE
#
# 24: # srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc
#
# 25:
#
# 26: # run scanscript
#
# 27: ./scanscript --np $SLURM_NTASKS --ppn $SLURM_NTASKS_PER_NODE --mps 4 --syscall='srun -l -K -n $SLURM_NTASKS ./gene_lumi_csc'
#
# 28:
#
# 29: set +x
#
#
# CODE RUN
# MAKING PARSER REMOTE SAVE DIRECTORY, /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale_90/ex-jet_97781_ion-scale_90_batch-7
# RESULT OF MAKING REMOTE SAVE DIRECTORY,
# OUT: Submitted batch job 9134196
#  ERROR?:
# OUT: Submitted batch job 9134196
#  ERROR?:
# SUBMITTED SBATCH ID: 9134196

# %%
ky_datagen.executor.check_finished()
# Out:
# CHECKING IF JOBS FINISHED: ['9134189', '9134190', '9134191', '9134192', '9134193', '9134194', '9134195', '9134196']
# FINISHED [ True  True  True  True  True False False  True]
# RUNNING SBATCH IDs:  ['9134194' '9134195']
#
#
# EXECUTOR, CHECK FINISHED False
# False

# %%
print(ky_datagen.remote_save_dir)
# Out:
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from config import Config
config = Config()
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
parser = GENE_scan_parser(config)
# save_dir = '/home/djdaniel/DEEPlasma/vault/data_gen_tutorial7'
save_dir=ky_datagen.remote_save_dir
data_set = ScanData2(name='jet_97781_ion-scale', config=config, parser=parser, save_dir=save_dir,  split_ratio=[0,0,1], categorise=True)
# Out:
# Initialising dataset
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 6 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 7 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 8 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 9 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 10 10
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 11 11
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 12 12
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 13 13
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 14 14
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 15 15
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 16 16
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 17 17
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 18 18
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 19 19
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 20 20
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 21 21
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 22 22
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 23 23
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 24 24
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# REASONS FOR GENE STOPPING DETECTED ['growthrate_converged']
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-0/scanfiles0000/parameters_0025
# DEBUG EXTRA 2 0001
# ky =  0.048351505
# DEBUG EXTRA 2, avg_kperpsq 25.518161354772526528
# DEBUG EXTRA 2 0002
# ky =  0.062166221
# DEBUG EXTRA 2, avg_kperpsq 42.183083443593098746
# DEBUG EXTRA 2 0003
# ky =  0.069073579
# DEBUG EXTRA 2, avg_kperpsq 52.077880962103347377
# DEBUG EXTRA 2 0004
# ky =  0.075980937
# DEBUG EXTRA 2, avg_kperpsq 63.014236130013602723
# DEBUG EXTRA 2 0005
# ky =  0.089795652
# DEBUG EXTRA 2, avg_kperpsq 88.011617453769482665
# DEBUG EXTRA 2 0006
# ky =  0.09670301
# DEBUG EXTRA 2, avg_kperpsq 102.07264541909010611
# DEBUG EXTRA 2 0007
# ky =  0.11051773
# DEBUG EXTRA 2, avg_kperpsq 133.3193839484647207
# DEBUG EXTRA 2 0008
# ky =  0.11742508
# DEBUG EXTRA 2, avg_kperpsq 150.50506495776039186
# DEBUG EXTRA 2 0009
# ky =  0.1312398
# DEBUG EXTRA 2, avg_kperpsq 188.00114998669288875
# DEBUG EXTRA 2 0010
# ky =  0.13814716
# DEBUG EXTRA 2, avg_kperpsq 208.31152987999679095
# DEBUG EXTRA 2 0011
# ky =  0.14505452
# DEBUG EXTRA 2, avg_kperpsq 229.66346802585909584
# DEBUG EXTRA 2 0012
# ky =  0.15886923
# DEBUG EXTRA 2, avg_kperpsq 275.49198439365411684
# DEBUG EXTRA 2 0013
# ky =  0.16577659
# DEBUG EXTRA 2, avg_kperpsq 299.96859578929536638
# DEBUG EXTRA 2 0014
# ky =  0.1795913
# DEBUG EXTRA 2, avg_kperpsq 352.04645413296162795
# DEBUG EXTRA 2 0015
# ky =  0.18649866
# DEBUG EXTRA 2, avg_kperpsq 379.64773877838180086
# DEBUG EXTRA 2 0016
# ky =  0.20031338
# DEBUG EXTRA 2, avg_kperpsq 437.97498282689744736
# DEBUG EXTRA 2 0017
# ky =  0.20722074
# DEBUG EXTRA 2, avg_kperpsq 468.70094222999277278
# DEBUG EXTRA 2 0018
# ky =  0.21412809
# DEBUG EXTRA 2, avg_kperpsq 500.46841314087587088
# DEBUG EXTRA 2 0019
# ky =  0.22794281
# DEBUG EXTRA 2, avg_kperpsq 567.1281201940661964
# DEBUG EXTRA 2 0020
# ky =  0.23485017
# DEBUG EXTRA 2, avg_kperpsq 602.0203110994990499
# DEBUG EXTRA 2 0021
# ky =  0.24866488
# DEBUG EXTRA 2, avg_kperpsq 674.92931338378984296
# DEBUG EXTRA 2 0022
# ky =  0.25557224
# DEBUG EXTRA 2, avg_kperpsq 712.94617753900158386
# DEBUG EXTRA 2 0023
# ky =  0.2624796
# DEBUG EXTRA 2, avg_kperpsq 752.004599946771555
# DEBUG EXTRA 2 0024
# ky =  0.27629431
# DEBUG EXTRA 2, avg_kperpsq 833.2460592041539536
# DEBUG EXTRA 2 0025
# ky =  0.28320167
# DEBUG EXTRA 2, avg_kperpsq 875.42915486170328787
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 6 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 7 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 8 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 9 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 10 10
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 11 11
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 12 12
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 13 13
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 14 14
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 15 15
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 16 16
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 17 17
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 18 18
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 19 19
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 20 20
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 21 21
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 22 22
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 23 23
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 24 24
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# REASONS FOR GENE STOPPING DETECTED ['growthrate_converged']
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-1/scanfiles0000/parameters_0025
# DEBUG EXTRA 2 0001
# ky =  0.29701639
# DEBUG EXTRA 2, avg_kperpsq 962.92002093447713873
# DEBUG EXTRA 2 0002
# ky =  0.30392375
# DEBUG EXTRA 2, avg_kperpsq 1008.22779134970128995
# DEBUG EXTRA 2 0003
# ky =  0.31773846
# DEBUG EXTRA 2, avg_kperpsq 1101.9679375746164673
# DEBUG EXTRA 2 0004
# ky =  0.32464582
# DEBUG EXTRA 2, avg_kperpsq 1150.4003812396195491
# DEBUG EXTRA 2 0005
# ky =  0.33155318
# DEBUG EXTRA 2, avg_kperpsq 1199.8743831571814655
# DEBUG EXTRA 2 0006
# ky =  0.34536789
# DEBUG EXTRA 2, avg_kperpsq 1301.9469863551883516
# DEBUG EXTRA 2 0007
# ky =  0.35227525
# DEBUG EXTRA 2, avg_kperpsq 1354.545661522529236
# DEBUG EXTRA 2 0008
# ky =  0.36608997
# DEBUG EXTRA 2, avg_kperpsq 1462.8676866148858332
# DEBUG EXTRA 2 0009
# ky =  0.37299732
# DEBUG EXTRA 2, avg_kperpsq 1518.5909551135272034
# DEBUG EXTRA 2 0010
# ky =  0.37990468
# DEBUG EXTRA 2, avg_kperpsq 1575.3558617832049908
# DEBUG EXTRA 2 0011
# ky =  0.3937194
# DEBUG EXTRA 2, avg_kperpsq 1692.0103498802363953
# DEBUG EXTRA 2 0012
# ky =  0.40062676
# DEBUG EXTRA 2, avg_kperpsq 1751.8999313075897895
# DEBUG EXTRA 2 0013
# ky =  0.41444147
# DEBUG EXTRA 2, avg_kperpsq 1874.8036784462211992
# DEBUG EXTRA 2 0014
# ky =  0.42134883
# DEBUG EXTRA 2, avg_kperpsq 1937.8179331233538273
# DEBUG EXTRA 2 0015
# ky =  0.43516355
# DEBUG EXTRA 2, avg_kperpsq 2066.9711172352935036
# DEBUG EXTRA 2 0016
# ky =  0.4420709
# DEBUG EXTRA 2, avg_kperpsq 2133.1099501647672043
# DEBUG EXTRA 2 0017
# ky =  0.44897826
# DEBUG EXTRA 2, avg_kperpsq 2200.2904363442370956
# DEBUG EXTRA 2 0018
# ky =  0.46279298
# DEBUG EXTRA 2, avg_kperpsq 2337.776083460851653
# DEBUG EXTRA 2 0019
# ky =  0.46970033
# DEBUG EXTRA 2, avg_kperpsq 2408.081141861080472
# DEBUG EXTRA 2 0020
# ky =  0.48351505
# DEBUG EXTRA 2, avg_kperpsq 2551.816135477252614
# DEBUG EXTRA 2 0021
# ky =  0.49042241
# DEBUG EXTRA 2, avg_kperpsq 2625.245969664176014
# DEBUG EXTRA 2 0022
# ky =  0.49732977
# DEBUG EXTRA 2, avg_kperpsq 2699.7173621036589253
# DEBUG EXTRA 2 0023
# ky =  0.51114448
# DEBUG EXTRA 2, avg_kperpsq 2851.7847101560063354
# DEBUG EXTRA 2 0024
# ky =  0.51805184
# DEBUG EXTRA 2, avg_kperpsq 2929.3807758452676535
# DEBUG EXTRA 2 0025
# ky =  0.53186656
# DEBUG EXTRA 2, avg_kperpsq 3087.6975819814645918
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 6 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 7 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 8 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 9 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 10 10
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 11 11
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 12 12
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 13 13
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 14 14
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 15 15
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 16 16
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 17 17
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 18 18
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 19 19
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 20 20
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 21 21
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 22 22
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 23 23
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 24 24
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# REASONS FOR GENE STOPPING DETECTED ['growthrate_converged']
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-2/scanfiles0000/parameters_0025
# DEBUG EXTRA 2 0001
# ky =  0.53877391
# DEBUG EXTRA 2, avg_kperpsq 3168.4182048125265667
# DEBUG EXTRA 2 0002
# ky =  0.55258863
# DEBUG EXTRA 2, avg_kperpsq 3332.9843574482823332
# DEBUG EXTRA 2 0003
# ky =  0.55949599
# DEBUG EXTRA 2, avg_kperpsq 3416.8297711449981757
# DEBUG EXTRA 2 0004
# ky =  0.56640335
# DEBUG EXTRA 2, avg_kperpsq 3501.7167430942708932
# DEBUG EXTRA 2 0005
# ky =  0.58021806
# DEBUG EXTRA 2, avg_kperpsq 3674.6152350872438743
# DEBUG EXTRA 2 0006
# ky =  0.58712542
# DEBUG EXTRA 2, avg_kperpsq 3762.6268802862966405
# DEBUG EXTRA 2 0007
# ky =  0.60094013
# DEBUG EXTRA 2, avg_kperpsq 3941.7747142551396466
# DEBUG EXTRA 2 0008
# ky =  0.60784749
# DEBUG EXTRA 2, avg_kperpsq 4032.9110327039717039
# DEBUG EXTRA 2 0009
# ky =  0.62166221
# DEBUG EXTRA 2, avg_kperpsq 4218.308344359309345
# DEBUG EXTRA 2 0010
# ky =  0.62856957
# DEBUG EXTRA 2, avg_kperpsq 4312.5693375658167925
# DEBUG EXTRA 2 0011
# ky =  0.63547692
# DEBUG EXTRA 2, avg_kperpsq 4407.8717502984658694
# DEBUG EXTRA 2 0012
# ky =  0.64929164
# DEBUG EXTRA 2, avg_kperpsq 4601.6015249584781963
# DEBUG EXTRA 2 0013
# ky =  0.656199
# DEBUG EXTRA 2, avg_kperpsq 4700.028749667322872
# DEBUG EXTRA 2 0014
# ky =  0.67001371
# DEBUG EXTRA 2, avg_kperpsq 4900.0077275767916145
# DEBUG EXTRA 2 0015
# ky =  0.67692107
# DEBUG EXTRA 2, avg_kperpsq 5001.559625535415249
# DEBUG EXTRA 2 0016
# ky =  0.68382843
# DEBUG EXTRA 2, avg_kperpsq 5104.153081746597184
# DEBUG EXTRA 2 0017
# ky =  0.69764314
# DEBUG EXTRA 2, avg_kperpsq 5312.4645166291561194
# DEBUG EXTRA 2 0018
# ky =  0.7045505
# DEBUG EXTRA 2, avg_kperpsq 5418.182646090116944
# DEBUG EXTRA 2 0019
# ky =  0.71836522
# DEBUG EXTRA 2, avg_kperpsq 5632.7435797697148194
# DEBUG EXTRA 2 0020
# ky =  0.72527258
# DEBUG EXTRA 2, avg_kperpsq 5741.5863839883485493
# DEBUG EXTRA 2 0021
# ky =  0.73908729
# DEBUG EXTRA 2, avg_kperpsq 5962.3965058384402496
# DEBUG EXTRA 2 0022
# ky =  0.74599465
# DEBUG EXTRA 2, avg_kperpsq 6074.363983306855591
# DEBUG EXTRA 2 0023
# ky =  0.75290201
# DEBUG EXTRA 2, avg_kperpsq 6187.373019027829061
# DEBUG EXTRA 2 0024
# ky =  0.76671672
# DEBUG EXTRA 2, avg_kperpsq 6416.515597851014406
# DEBUG EXTRA 2 0025
# ky =  0.77362408
# DEBUG EXTRA 2, avg_kperpsq 6532.649306821766791
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 6 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 7 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 8 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 9 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 10 10
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 11 11
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 12 12
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 13 13
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 14 14
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 15 15
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 16 16
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 17 17
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 18 18
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 19 19
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 20 20
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 21 21
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 22 22
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 23 23
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 24 24
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# REASONS FOR GENE STOPPING DETECTED ['growthrate_converged']
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-3/scanfiles0000/parameters_0012
# ...
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-6/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-6/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-6/scanfiles0000/parameters_0006
# DEBUG EXTRA 2 0001
# ky =  1.5196187
# DEBUG EXTRA 2, avg_kperpsq 25205.693125057132809
# DEBUG EXTRA 2 0002
# ky =  1.5265261
# DEBUG EXTRA 2, avg_kperpsq 25435.357977331350487
# DEBUG EXTRA 2 0003
# ky =  1.5403408
# DEBUG EXTRA 2, avg_kperpsq 25897.809030219285408
# DEBUG EXTRA 2 0004
# ky =  1.5472482
# DEBUG EXTRA 2, avg_kperpsq 26130.598578361744247
# DEBUG EXTRA 2 0005
# ky =  1.5610629
# DEBUG EXTRA 2, avg_kperpsq 26599.298977749223699
# DEBUG EXTRA 2 0006
# ky =  1.5679702
# DEBUG EXTRA 2, avg_kperpsq 26835.209798836369595
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 6 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 7 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 8 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 9 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 10 10
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 11 11
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 12 12
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 13 13
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 14 14
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 15 15
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 16 16
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 17 17
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 18 18
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 19 19
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 20 20
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 21 21
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 22 22
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 23 23
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 24 24
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# REASONS FOR GENE STOPPING DETECTED ['growthrate_converged']
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0025
# READING FLUXES
# READING FLUXES
# READING FLUXES
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0001
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0002
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0003
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0004
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0005
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0006
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0007
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0008
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0009
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0010
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0011
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0012
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0013
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0014
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0015
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0016
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0017
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0018
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0019
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0020
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0021
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0022
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0023
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0024
# /scratch/project_462000451/gene_out/gene_auto_97781/jet_97781_ion-scale/ex-jet_97781_ion-scale_batch-7/scanfiles0000/parameters_0025
# DEBUG EXTRA 2 0001
# ky =  1.7613763
# DEBUG EXTRA 2, avg_kperpsq 33863.643460630425523
# DEBUG EXTRA 2 0002
# ky =  1.775191
# DEBUG EXTRA 2, avg_kperpsq 34396.92036009223138
# DEBUG EXTRA 2 0003
# ky =  1.7820983
# DEBUG EXTRA 2, avg_kperpsq 34665.11919749268223
# DEBUG EXTRA 2 0004
# ky =  1.795913
# DEBUG EXTRA 2, avg_kperpsq 35204.645413296154857
# DEBUG EXTRA 2 0005
# ky =  1.8028204
# DEBUG EXTRA 2, avg_kperpsq 35475.97282185707618
# DEBUG EXTRA 2 0006
# ky =  1.8166351
# DEBUG EXTRA 2, avg_kperpsq 36021.748384160088904
# DEBUG EXTRA 2 0007
# ky =  1.8235425
# DEBUG EXTRA 2, avg_kperpsq 36296.200488589240255
# DEBUG EXTRA 2 0008
# ky =  1.8304498
# DEBUG EXTRA 2, avg_kperpsq 36571.69016741018936
# DEBUG EXTRA 2 0009
# ky =  1.8442646
# DEBUG EXTRA 2, avg_kperpsq 37125.80219768920466
# DEBUG EXTRA 2 0010
# ky =  1.8511719
# DEBUG EXTRA 2, avg_kperpsq 37404.416527141459728
# DEBUG EXTRA 2 0011
# ky =  1.8649866
# DEBUG EXTRA 2, avg_kperpsq 37964.77387783817832
# DEBUG EXTRA 2 0012
# ky =  1.871894
# DEBUG EXTRA 2, avg_kperpsq 38246.516929240523115
# DEBUG EXTRA 2 0013
# ky =  1.8857087
# DEBUG EXTRA 2, avg_kperpsq 38813.12362643678241
# DEBUG EXTRA 2 0014
# ky =  1.8926161
# DEBUG EXTRA 2, avg_kperpsq 39097.991373707367995
# DEBUG EXTRA 2 0015
# ky =  1.8995234
# DEBUG EXTRA 2, avg_kperpsq 39383.896544580131582
# DEBUG EXTRA 2 0016
# ky =  1.9133381
# DEBUG EXTRA 2, avg_kperpsq 39958.835683670539265
# DEBUG EXTRA 2 0017
# ky =  1.9202455
# DEBUG EXTRA 2, avg_kperpsq 40247.869682046082055
# DEBUG EXTRA 2 0018
# ky =  1.9340602
# DEBUG EXTRA 2, avg_kperpsq 40829.058167636041823
# DEBUG EXTRA 2 0019
# ky =  1.9409676
# DEBUG EXTRA 2, avg_kperpsq 41121.21686187982354
# DEBUG EXTRA 2 0020
# ky =  1.9478749
# DEBUG EXTRA 2, avg_kperpsq 41414.41287417306488
# DEBUG EXTRA 2 0021
# ky =  1.9616896
# DEBUG EXTRA 2, avg_kperpsq 42003.9338016571697
# DEBUG EXTRA 2 0022
# ky =  1.968597
# DEBUG EXTRA 2, avg_kperpsq 42300.258747005907647
# DEBUG EXTRA 2 0023
# ky =  1.9824117
# DEBUG EXTRA 2, avg_kperpsq 42896.02902098956697
# DEBUG EXTRA 2 0024
# ky =  1.9893191
# DEBUG EXTRA 2, avg_kperpsq 43195.478662206535528
# DEBUG EXTRA 2 0025
# ky =  2.0031338
# DEBUG EXTRA 2, avg_kperpsq 43797.498282689744777
# SETTING VARIABLES
# End of SCAN DATA init
# /pfs/lustrep4/projappl/project_462000451/DEEPlasma/GENE_ML/gene_ml/dataset/ScanData.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.rest_df_no_nan['data_categorie'] = random_categories

# %%
data_set.df.iloc[147:]
# Out:
#        kymin1 growthrate frequency  run_time    termination_reason  \
# 147  1.490452     0.5380    1.2640   613.259  growthrate_converged
# 148  1.500251     0.5370    1.2690   642.520  growthrate_converged
# 149  1.510050     0.5330    1.2780   833.314  growthrate_converged
# 150  1.519849     0.5310    1.2830   902.115  growthrate_converged
# 151  1.529648     0.5300    1.2880  1109.882  growthrate_converged
# 152  1.539447     0.5270    1.2970  1674.866  growthrate_converged
# 153  1.549246     0.5250    1.3010  2274.760  growthrate_converged
# 154  1.559045        NaN       NaN  7200.144                   NaN
# 155  1.568844        NaN       NaN       NaN                   NaN
# 156  1.578643        NaN       NaN       NaN                   NaN
# 157  1.588442        NaN       NaN       NaN                   NaN
# 158  1.598241        NaN       NaN       NaN                   NaN
# 159  1.608040        NaN       NaN       NaN                   NaN
# 160  1.617839        NaN       NaN       NaN                   NaN
# 161  1.627638        NaN       NaN       NaN                   NaN
# 162  1.637437        NaN       NaN       NaN                   NaN
# 163  1.647236        NaN       NaN       NaN                   NaN
# 164  1.657035        NaN       NaN       NaN                   NaN
# 165  1.666834        NaN       NaN       NaN                   NaN
# 166  1.676633        NaN       NaN       NaN                   NaN
# 167  1.686432        NaN       NaN       NaN                   NaN
# 168  1.696231        NaN       NaN       NaN                   NaN
# 169  1.706030        NaN       NaN       NaN                   NaN
# 170  1.715829        NaN       NaN       NaN                   NaN
# 171  1.725628        NaN       NaN       NaN                   NaN
# 172  1.735427        NaN       NaN       NaN                   NaN
# 173  1.745226        NaN       NaN       NaN                   NaN
# 174  1.755025        NaN       NaN       NaN                   NaN
# 175  1.764824     0.6250   -0.9860   150.291  growthrate_converged
# 176  1.774623     0.6330   -0.9930   173.352  growthrate_converged
# 177  1.784422     0.6370   -0.9980   160.640  growthrate_converged
# 178  1.794221     0.6450   -1.0050   164.565  growthrate_converged
# 179  1.804020     0.6480   -1.0090   149.933  growthrate_converged
# 180  1.813819     0.6560   -1.0160   150.190  growthrate_converged
# 181  1.823618     0.6600   -1.0190   142.689  growthrate_converged
# 182  1.833417     0.6650   -1.0220   138.133  growthrate_converged
# 183  1.843216     0.6730   -1.0300   134.050  growthrate_converged
# 184  1.853015     0.6770   -1.0330   130.898  growthrate_converged
# 185  1.862814     0.6850   -1.0400   132.268  growthrate_converged
# 186  1.872613     0.6890   -1.0440   124.328  growthrate_converged
# 187  1.882412     0.6970   -1.0510   124.411  growthrate_converged
# 188  1.892211     0.7020   -1.0550   118.490  growthrate_converged
# 189  1.902010     0.7050   -1.0580   123.454  growthrate_converged
# 190  1.911809     0.7140   -1.0650   115.247  growthrate_converged
# 191  1.921608     0.7180   -1.0690   119.061  growthrate_converged
# 192  1.931407     0.7270   -1.0750   108.134  growthrate_converged
# 193  1.941206     0.7310   -1.0780   115.421  growthrate_converged
# 194  1.951005     0.7350   -1.0810   114.665  growthrate_converged
# 195  1.960804     0.7440   -1.0890   110.464  growthrate_converged
# 196  1.970603     0.7480   -1.0920   111.011  growthrate_converged
# 197  1.980402     0.7560   -1.0990   109.843  growthrate_converged
# 198  1.990201     0.7600   -1.1020   110.381  growthrate_converged
# 199  2.000000     0.7690   -1.1080   108.014  growthrate_converged
#
#     fingerprint  ratio_iheat_eheat  ratio_eparticle_eheat em_categorisation  \
# 147      [None]           1.264964              -0.898641            no_MTM
# 148      [None]           1.258110              -0.904927            no_MTM
# 149      [None]           1.245158              -0.919652            no_MTM
# 150      [None]           1.238503              -0.927619            no_MTM
# 151      [None]           1.232521              -0.934766            no_MTM
# 152      [None]           1.219833              -0.948699            no_MTM
# 153      [None]           1.213671              -0.955927            no_MTM
# 154      [None]           1.201772              -0.970617            no_MTM
# 155      [None]           0.188477              -0.834891            no_MTM
# 156      [None]                NaN                    NaN            no_MTM
# 157      [None]                NaN                    NaN            no_MTM
# 158      [None]                NaN                    NaN            no_MTM
# 159      [None]                NaN                    NaN            no_MTM
# 160      [None]                NaN                    NaN            no_MTM
# 161      [None]                NaN                    NaN            no_MTM
# 162      [None]                NaN                    NaN            no_MTM
# 163      [None]                NaN                    NaN            no_MTM
# 164      [None]                NaN                    NaN            no_MTM
# 165      [None]                NaN                    NaN            no_MTM
# 166      [None]                NaN                    NaN            no_MTM
# 167      [None]                NaN                    NaN            no_MTM
# 168      [None]                NaN                    NaN            no_MTM
# 169      [None]                NaN                    NaN            no_MTM
# 170      [None]                NaN                    NaN            no_MTM
# 171      [None]                NaN                    NaN            no_MTM
# 172      [None]                NaN                    NaN            no_MTM
# 173      [None]                NaN                    NaN            no_MTM
# 174      [None]                NaN                    NaN            no_MTM
# 175      [None]           0.119228              -0.504065            no_MTM
# 176      [None]           0.118800              -0.502266            no_MTM
# 177      [None]           0.118664              -0.502002            no_MTM
# 178      [None]           0.118349              -0.500626            no_MTM
# 179      [None]           0.118285              -0.500328            no_MTM
# 180      [None]           0.117982              -0.498937            no_MTM
# 181      [None]           0.117767              -0.498021            no_MTM
# 182      [None]           0.117435              -0.496233            no_MTM
# 183      [None]           0.117153              -0.495298            no_MTM
# 184      [None]           0.117089              -0.494775            no_MTM
# 185      [None]           0.116632              -0.492829            no_MTM
# 186      [None]           0.116757              -0.493636            no_MTM
# 187      [None]           0.116497              -0.492427            no_MTM
# 188      [None]           0.116098              -0.490614            no_MTM
# 189      [None]           0.116150              -0.490781            no_MTM
# 190      [None]           0.115995              -0.490215            no_MTM
# 191      [None]           0.115729              -0.489171            no_MTM
# 192      [None]           0.115384              -0.487527            no_MTM
# 193      [None]           0.115481              -0.487990            no_MTM
# 194      [None]           0.115311              -0.487224            no_MTM
# 195      [None]           0.115032              -0.486204            no_MTM
# 196      [None]           0.114993              -0.486102            no_MTM
# 197      [None]           0.114896              -0.485605            no_MTM
# 198      [None]           0.114840              -0.485321            no_MTM
# 199      [None]           0.114789              -0.484807            no_MTM
#
#      particle_diff_Electrons  ...  particle_electromagnetic_Electrons  \
# 147            -8.013631e+00  ...                       -7.629900e-01
# 148            -2.784174e+06  ...                       -2.620300e+05
# 149            -3.372292e+06  ...                       -3.094600e+05
# 150            -6.638961e+19  ...                       -6.010000e+18
# 151            -3.708411e+15  ...                       -3.317500e+14
# 152            -7.955837e+10  ...                       -6.948400e+09
# 153            -2.627382e+08  ...                       -2.266800e+07
# 154            -1.000030e+22  ...                       -8.421400e+20
# 155            -2.095652e+01  ...                        2.039900e-02
# 156                      NaN  ...                                 NaN
# 157                      NaN  ...                                 NaN
# 158                      NaN  ...                                 NaN
# 159                      NaN  ...                                 NaN
# 160                      NaN  ...                                 NaN
# 161                      NaN  ...                                 NaN
# 162                      NaN  ...                                 NaN
# 163                      NaN  ...                                 NaN
# 164                      NaN  ...                                 NaN
# 165                      NaN  ...                                 NaN
# 166                      NaN  ...                                 NaN
# 167                      NaN  ...                                 NaN
# 168                      NaN  ...                                 NaN
# 169                      NaN  ...                                 NaN
# 170                      NaN  ...                                 NaN
# 171                      NaN  ...                                 NaN
# 172                      NaN  ...                                 NaN
# 173                      NaN  ...                                 NaN
# 174                      NaN  ...                                 NaN
# 175            -5.548304e+21  ...                        2.387200e+18
# 176            -4.537765e+21  ...                        1.883700e+18
# 177            -9.366729e+19  ...                        3.909400e+16
# 178            -7.951606e+19  ...                        3.199900e+16
# 179            -3.238469e+18  ...                        1.275100e+15
# 180            -2.583528e+18  ...                        9.767300e+14
# 181            -1.917866e+17  ...                        7.156600e+13
# 182            -4.471998e+16  ...                        1.598000e+13
# 183            -1.742830e+16  ...                        6.163000e+12
# 184            -3.565201e+15  ...                        1.203000e+12
# 185            -2.065936e+15  ...                        6.774700e+11
# 186            -4.571300e+14  ...                        1.493600e+11
# 187            -3.771208e+14  ...                        1.177400e+11
# 188            -8.606514e+13  ...                        2.653200e+10
# 189            -2.428961e+14  ...                        7.243100e+10
# 190            -1.932505e+13  ...                        5.608100e+09
# 191            -5.895413e+13  ...                        1.714300e+10
# 192            -6.407682e+12  ...                        1.769600e+09
# 193            -1.722365e+13  ...                        4.631700e+09
# 194            -1.412321e+13  ...                        3.722200e+09
# 195            -5.398741e+12  ...                        1.409000e+09
# 196            -4.660615e+12  ...                        1.203100e+09
# 197            -4.712084e+12  ...                        1.174900e+09
# 198            -3.963076e+12  ...                        9.726300e+08
# 199            -2.381276e+12  ...                        5.576200e+08
#
#      heat_electrostatic_Electrons  heat_electromagnetic_Electrons  \
# 147                  1.405300e+02                   -7.803900e+00
# 148                  4.835700e+07                   -2.636500e+06
# 149                  5.730100e+07                   -3.011000e+06
# 150                  1.115000e+21                   -5.751100e+19
# 151                  6.163000e+16                   -3.118000e+15
# 152                  1.295500e+12                   -6.301000e+10
# 153                  4.233900e+09                   -2.018500e+08
# 154                  1.578000e+23                   -7.220400e+21
# 155                  3.748500e+02                    4.720400e+00
# 156                           NaN                             NaN
# 157                           NaN                             NaN
# 158                           NaN                             NaN
# 159                           NaN                             NaN
# 160                           NaN                             NaN
# 161                           NaN                             NaN
# 162                           NaN                             NaN
# 163                           NaN                             NaN
# 164                           NaN                             NaN
# 165                           NaN                             NaN
# 166                           NaN                             NaN
# 167                           NaN                             NaN
# 168                           NaN                             NaN
# 169                           NaN                             NaN
# 170                           NaN                             NaN
# 171                           NaN                             NaN
# 172                           NaN                             NaN
# 173                           NaN                             NaN
# 174                           NaN                             NaN
# 175                  1.774200e+23                    2.621900e+21
# 176                  1.456600e+23                    2.177900e+21
# 177                  3.008100e+21                    4.532000e+19
# 178                  2.561100e+21                    3.895400e+19
# 179                  1.043700e+20                    1.593100e+18
# 180                  8.351200e+19                    1.284000e+18
# 181                  6.211700e+18                    9.596400e+16
# 182                  1.454200e+18                    2.249600e+16
# 183                  5.678500e+17                    8.858000e+15
# 184                  1.163000e+17                    1.812600e+15
# 185                  6.768200e+16                    1.061700e+15
# 186                  1.494800e+16                    2.352700e+14
# 187                  1.236500e+16                    1.950200e+14
# 188                  2.833400e+15                    4.478500e+13
# 189                  7.993200e+15                    1.266400e+14
# 190                  6.367500e+14                    1.010100e+13
# 191                  1.947100e+15                    3.090400e+13
# 192                  2.124000e+14                    3.393200e+12
# 193                  5.703500e+14                    9.084800e+12
# 194                  4.685100e+14                    7.450300e+12
# 195                  1.795000e+14                    2.864800e+12
# 196                  1.549900e+14                    2.478000e+12
# 197                  1.569000e+14                    2.488100e+12
# 198                  1.320400e+14                    2.099700e+12
# 199                  7.944600e+13                    1.248800e+12
#
#      particle_electrostatic_Ions  particle_electromagnetic_Ions  \
# 147                -1.256900e+01                  -7.629900e-01
# 148                -4.369900e+06                  -2.620300e+05
# 149                -5.300900e+06                  -3.094600e+05
# 150                -1.044400e+20                  -6.010000e+18
# 151                -5.837800e+15                  -3.317500e+14
# 152                -1.254100e+11                  -6.948400e+09
# 153                -4.144400e+08                  -2.266800e+07
# 154                -1.579500e+22                  -8.421400e+20
# 155                -3.488500e+01                   2.039900e-02
# 156                          NaN                            NaN
# 157                          NaN                            NaN
# 158                          NaN                            NaN
# 159                          NaN                            NaN
# 160                          NaN                            NaN
# 161                          NaN                            NaN
# 162                          NaN                            NaN
# 163                          NaN                            NaN
# 164                          NaN                            NaN
# 165                          NaN                            NaN
# 166                          NaN                            NaN
# 167                          NaN                            NaN
# 168                          NaN                            NaN
# 169                          NaN                            NaN
# 170                          NaN                            NaN
# 171                          NaN                            NaN
# 172                          NaN                            NaN
# 173                          NaN                            NaN
# 174                          NaN                            NaN
# 175                -9.232900e+21                   2.387200e+18
# 176                -7.551200e+21                   1.883700e+18
# 177                -1.558700e+20                   3.909400e+16
# 178                -1.323200e+20                   3.199900e+16
# 179                -5.389000e+18                   1.275100e+15
# 180                -4.299100e+18                   9.767300e+14
# 181                -3.191400e+17                   7.156600e+13
# 182                -7.441500e+16                   1.598000e+13
# 183                -2.900100e+16                   6.163000e+12
# 184                -5.932500e+15                   1.203000e+12
# 185                -3.437700e+15                   6.774700e+11
# 186                -7.606600e+14                   1.493600e+11
# 187                -6.275200e+14                   1.177400e+11
# 188                -1.432100e+14                   2.653200e+10
# 189                -4.041700e+14                   7.243100e+10
# 190                -3.215600e+13                   5.608100e+09
# 191                -9.809700e+13                   1.714300e+10
# 192                -1.066200e+13                   1.769600e+09
# 193                -2.865900e+13                   4.631700e+09
# 194                -2.350000e+13                   3.722200e+09
# 195                -8.983100e+12                   1.409000e+09
# 196                -7.754900e+12                   1.203100e+09
# 197                -7.840500e+12                   1.174900e+09
# 198                -6.594200e+12                   9.726300e+08
# 199                -3.962200e+12                   5.576200e+08
#
#      heat_electrostatic_Ions  heat_electromagnetic_Ions  categorisation  \
# 147             2.025400e+02              -2.644900e+00         Nothing
# 148             6.931500e+07              -9.063000e+05         Nothing
# 149             8.128400e+07              -1.065600e+06         Nothing
# 150             1.573000e+21              -2.064900e+19         Nothing
# 151             8.652200e+16              -1.137300e+15         Nothing
# 152             1.799400e+12              -2.371600e+10         Nothing
# 153             5.849800e+09              -7.720200e+07         Nothing
# 154             2.157900e+23              -2.855600e+21         Nothing
# 155            -1.100200e+01               1.205100e-01         Nothing
# 156                      NaN                        NaN         Nothing
# 157                      NaN                        NaN         Nothing
# 158                      NaN                        NaN         Nothing
# 159                      NaN                        NaN         Nothing
# 160                      NaN                        NaN         Nothing
# 161                      NaN                        NaN         Nothing
# 162                      NaN                        NaN         Nothing
# 163                      NaN                        NaN         Nothing
# 164                      NaN                        NaN         Nothing
# 165                      NaN                        NaN         Nothing
# 166                      NaN                        NaN         Nothing
# 167                      NaN                        NaN         Nothing
# 168                      NaN                        NaN         Nothing
# 169                      NaN                        NaN         Nothing
# 170                      NaN                        NaN         Nothing
# 171                      NaN                        NaN         Nothing
# 172                      NaN                        NaN         Nothing
# 173                      NaN                        NaN         Nothing
# 174                      NaN                        NaN         Nothing
# 175            -1.618200e+21               2.627000e+19         Nothing
# 176            -1.323600e+21               2.101400e+19         Nothing
# 177            -2.761200e+19               4.313000e+17         Nothing
# 178            -2.339700e+19               3.579400e+17         Nothing
# 179            -9.518800e+17               1.439600e+16         Nothing
# 180            -7.561500e+17               1.121900e+16         Nothing
# 181            -5.611700e+16               8.249100e+14         Nothing
# 182            -1.290500e+16               1.892900e+14         Nothing
# 183            -5.074500e+15               7.257400e+13         Nothing
# 184            -1.028500e+15               1.458400e+13         Nothing
# 185            -5.954300e+14               8.288700e+12         Nothing
# 186            -1.330700e+14               1.817600e+12         Nothing
# 187            -1.093100e+14               1.464100e+12         Nothing
# 188            -2.483100e+13               3.313200e+11         Nothing
# 189            -6.992700e+13               9.215700e+11         Nothing
# 190            -5.580500e+12               7.183900e+10         Nothing
# 191            -1.707100e+13               2.178100e+11         Nothing
# 192            -1.842600e+12               2.312200e+10         Nothing
# 193            -4.961200e+12               6.130500e+10         Nothing
# 194            -4.060400e+12               4.971300e+10         Nothing
# 195            -1.560800e+12               1.870900e+10         Nothing
# 196            -1.350300e+12               1.599800e+10         Nothing
# 197            -1.360700e+12               1.582400e+10         Nothing
# 198            -1.142200e+12               1.317700e+10         Nothing
# 199            -6.786500e+11               7.726000e+09         Nothing
#
#      avg_kperp_squared  mixing_length
# 147       24297.455933       0.000022
# 148       24522.954534       0.000022
# 149       24977.073145       0.000021
# 150       25205.693125       0.000021
# 151       25435.357977       0.000021
# 152       25897.809030       0.000020
# 153       26130.598578       0.000020
# 154       26599.298978            NaN
# 155       26835.209799            NaN
# 156                NaN            NaN
# 157                NaN            NaN
# 158                NaN            NaN
# 159                NaN            NaN
# 160                NaN            NaN
# 161                NaN            NaN
# 162                NaN            NaN
# 163                NaN            NaN
# 164                NaN            NaN
# 165                NaN            NaN
# 166                NaN            NaN
# 167                NaN            NaN
# 168                NaN            NaN
# 169                NaN            NaN
# 170                NaN            NaN
# 171                NaN            NaN
# 172                NaN            NaN
# 173                NaN            NaN
# 174                NaN            NaN
# 175       33863.643461       0.000018
# 176       34396.920360       0.000018
# 177       34665.119197       0.000018
# 178       35204.645413       0.000018
# 179       35475.972822       0.000018
# 180       36021.748384       0.000018
# 181       36296.200489       0.000018
# 182       36571.690167       0.000018
# 183       37125.802198       0.000018
# 184       37404.416527       0.000018
# 185       37964.773878       0.000018
# 186       38246.516929       0.000018
# 187       38813.123626       0.000018
# 188       39097.991374       0.000018
# 189       39383.896545       0.000018
# 190       39958.835684       0.000018
# 191       40247.869682       0.000018
# 192       40829.058168       0.000018
# 193       41121.216862       0.000018
# 194       41414.412874       0.000018
# 195       42003.933802       0.000018
# 196       42300.258747       0.000018
# 197       42896.029021       0.000018
# 198       43195.478662       0.000018
# 199       43797.498283       0.000018
#
# [53 rows x 28 columns]

# %%
data_set.df.iloc[147:]
# Out:
#        kymin1 growthrate frequency  run_time    termination_reason  \
# 147  1.490452     0.5380    1.2640   613.259  growthrate_converged
# 148  1.500251     0.5370    1.2690   642.520  growthrate_converged
# 149  1.510050     0.5330    1.2780   833.314  growthrate_converged
# 150  1.519849     0.5310    1.2830   902.115  growthrate_converged
# 151  1.529648     0.5300    1.2880  1109.882  growthrate_converged
# 152  1.539447     0.5270    1.2970  1674.866  growthrate_converged
# 153  1.549246     0.5250    1.3010  2274.760  growthrate_converged
# 154  1.559045        NaN       NaN  7200.144                   NaN
# 155  1.568844        NaN       NaN       NaN                   NaN
# 156  1.578643        NaN       NaN       NaN                   NaN
# 157  1.588442        NaN       NaN       NaN                   NaN
# 158  1.598241        NaN       NaN       NaN                   NaN
# 159  1.608040        NaN       NaN       NaN                   NaN
# 160  1.617839        NaN       NaN       NaN                   NaN
# 161  1.627638        NaN       NaN       NaN                   NaN
# 162  1.637437        NaN       NaN       NaN                   NaN
# 163  1.647236        NaN       NaN       NaN                   NaN
# 164  1.657035        NaN       NaN       NaN                   NaN
# 165  1.666834        NaN       NaN       NaN                   NaN
# 166  1.676633        NaN       NaN       NaN                   NaN
# 167  1.686432        NaN       NaN       NaN                   NaN
# 168  1.696231        NaN       NaN       NaN                   NaN
# 169  1.706030        NaN       NaN       NaN                   NaN
# 170  1.715829        NaN       NaN       NaN                   NaN
# 171  1.725628        NaN       NaN       NaN                   NaN
# 172  1.735427        NaN       NaN       NaN                   NaN
# 173  1.745226        NaN       NaN       NaN                   NaN
# 174  1.755025        NaN       NaN       NaN                   NaN
# 175  1.764824     0.6250   -0.9860   150.291  growthrate_converged
# 176  1.774623     0.6330   -0.9930   173.352  growthrate_converged
# 177  1.784422     0.6370   -0.9980   160.640  growthrate_converged
# 178  1.794221     0.6450   -1.0050   164.565  growthrate_converged
# 179  1.804020     0.6480   -1.0090   149.933  growthrate_converged
# 180  1.813819     0.6560   -1.0160   150.190  growthrate_converged
# 181  1.823618     0.6600   -1.0190   142.689  growthrate_converged
# 182  1.833417     0.6650   -1.0220   138.133  growthrate_converged
# 183  1.843216     0.6730   -1.0300   134.050  growthrate_converged
# 184  1.853015     0.6770   -1.0330   130.898  growthrate_converged
# 185  1.862814     0.6850   -1.0400   132.268  growthrate_converged
# 186  1.872613     0.6890   -1.0440   124.328  growthrate_converged
# 187  1.882412     0.6970   -1.0510   124.411  growthrate_converged
# 188  1.892211     0.7020   -1.0550   118.490  growthrate_converged
# 189  1.902010     0.7050   -1.0580   123.454  growthrate_converged
# 190  1.911809     0.7140   -1.0650   115.247  growthrate_converged
# 191  1.921608     0.7180   -1.0690   119.061  growthrate_converged
# 192  1.931407     0.7270   -1.0750   108.134  growthrate_converged
# 193  1.941206     0.7310   -1.0780   115.421  growthrate_converged
# 194  1.951005     0.7350   -1.0810   114.665  growthrate_converged
# 195  1.960804     0.7440   -1.0890   110.464  growthrate_converged
# 196  1.970603     0.7480   -1.0920   111.011  growthrate_converged
# 197  1.980402     0.7560   -1.0990   109.843  growthrate_converged
# 198  1.990201     0.7600   -1.1020   110.381  growthrate_converged
# 199  2.000000     0.7690   -1.1080   108.014  growthrate_converged
#
#     fingerprint  ratio_iheat_eheat  ratio_eparticle_eheat em_categorisation  \
# 147      [None]           1.264964              -0.898641            no_MTM
# 148      [None]           1.258110              -0.904927            no_MTM
# 149      [None]           1.245158              -0.919652            no_MTM
# 150      [None]           1.238503              -0.927619            no_MTM
# 151      [None]           1.232521              -0.934766            no_MTM
# 152      [None]           1.219833              -0.948699            no_MTM
# 153      [None]           1.213671              -0.955927            no_MTM
# 154      [None]           1.201772              -0.970617            no_MTM
# 155      [None]           0.188477              -0.834891            no_MTM
# 156         NaN                NaN                    NaN               NaN
# 157         NaN                NaN                    NaN               NaN
# 158         NaN                NaN                    NaN               NaN
# 159         NaN                NaN                    NaN               NaN
# 160         NaN                NaN                    NaN               NaN
# 161         NaN                NaN                    NaN               NaN
# 162         NaN                NaN                    NaN               NaN
# 163         NaN                NaN                    NaN               NaN
# 164         NaN                NaN                    NaN               NaN
# 165         NaN                NaN                    NaN               NaN
# 166         NaN                NaN                    NaN               NaN
# 167         NaN                NaN                    NaN               NaN
# 168         NaN                NaN                    NaN               NaN
# 169         NaN                NaN                    NaN               NaN
# 170         NaN                NaN                    NaN               NaN
# 171         NaN                NaN                    NaN               NaN
# 172         NaN                NaN                    NaN               NaN
# 173         NaN                NaN                    NaN               NaN
# 174         NaN                NaN                    NaN               NaN
# 175      [None]           0.119228              -0.504065            no_MTM
# 176      [None]           0.118800              -0.502266            no_MTM
# 177      [None]           0.118664              -0.502002            no_MTM
# 178      [None]           0.118349              -0.500626            no_MTM
# 179      [None]           0.118285              -0.500328            no_MTM
# 180      [None]           0.117982              -0.498937            no_MTM
# 181      [None]           0.117767              -0.498021            no_MTM
# 182      [None]           0.117435              -0.496233            no_MTM
# 183      [None]           0.117153              -0.495298            no_MTM
# 184      [None]           0.117089              -0.494775            no_MTM
# 185      [None]           0.116632              -0.492829            no_MTM
# 186      [None]           0.116757              -0.493636            no_MTM
# 187      [None]           0.116497              -0.492427            no_MTM
# 188      [None]           0.116098              -0.490614            no_MTM
# 189      [None]           0.116150              -0.490781            no_MTM
# 190      [None]           0.115995              -0.490215            no_MTM
# 191      [None]           0.115729              -0.489171            no_MTM
# 192      [None]           0.115384              -0.487527            no_MTM
# 193      [None]           0.115481              -0.487990            no_MTM
# 194      [None]           0.115311              -0.487224            no_MTM
# 195      [None]           0.115032              -0.486204            no_MTM
# 196      [None]           0.114993              -0.486102            no_MTM
# 197      [None]           0.114896              -0.485605            no_MTM
# 198      [None]           0.114840              -0.485321            no_MTM
# 199      [None]           0.114789              -0.484807            no_MTM
#
#      particle_diff_Electrons  ...  particle_electromagnetic_Electrons  \
# 147            -8.013631e+00  ...                       -7.629900e-01
# 148            -2.784174e+06  ...                       -2.620300e+05
# 149            -3.372292e+06  ...                       -3.094600e+05
# 150            -6.638961e+19  ...                       -6.010000e+18
# 151            -3.708411e+15  ...                       -3.317500e+14
# 152            -7.955837e+10  ...                       -6.948400e+09
# 153            -2.627382e+08  ...                       -2.266800e+07
# 154            -1.000030e+22  ...                       -8.421400e+20
# 155            -2.095652e+01  ...                        2.039900e-02
# 156                      NaN  ...                                 NaN
# 157                      NaN  ...                                 NaN
# 158                      NaN  ...                                 NaN
# 159                      NaN  ...                                 NaN
# 160                      NaN  ...                                 NaN
# 161                      NaN  ...                                 NaN
# 162                      NaN  ...                                 NaN
# 163                      NaN  ...                                 NaN
# 164                      NaN  ...                                 NaN
# 165                      NaN  ...                                 NaN
# 166                      NaN  ...                                 NaN
# 167                      NaN  ...                                 NaN
# 168                      NaN  ...                                 NaN
# 169                      NaN  ...                                 NaN
# 170                      NaN  ...                                 NaN
# 171                      NaN  ...                                 NaN
# 172                      NaN  ...                                 NaN
# 173                      NaN  ...                                 NaN
# 174                      NaN  ...                                 NaN
# 175            -5.548304e+21  ...                        2.387200e+18
# 176            -4.537765e+21  ...                        1.883700e+18
# 177            -9.366729e+19  ...                        3.909400e+16
# 178            -7.951606e+19  ...                        3.199900e+16
# 179            -3.238469e+18  ...                        1.275100e+15
# 180            -2.583528e+18  ...                        9.767300e+14
# 181            -1.917866e+17  ...                        7.156600e+13
# 182            -4.471998e+16  ...                        1.598000e+13
# 183            -1.742830e+16  ...                        6.163000e+12
# 184            -3.565201e+15  ...                        1.203000e+12
# 185            -2.065936e+15  ...                        6.774700e+11
# 186            -4.571300e+14  ...                        1.493600e+11
# 187            -3.771208e+14  ...                        1.177400e+11
# 188            -8.606514e+13  ...                        2.653200e+10
# 189            -2.428961e+14  ...                        7.243100e+10
# 190            -1.932505e+13  ...                        5.608100e+09
# 191            -5.895413e+13  ...                        1.714300e+10
# 192            -6.407682e+12  ...                        1.769600e+09
# 193            -1.722365e+13  ...                        4.631700e+09
# 194            -1.412321e+13  ...                        3.722200e+09
# 195            -5.398741e+12  ...                        1.409000e+09
# 196            -4.660615e+12  ...                        1.203100e+09
# 197            -4.712084e+12  ...                        1.174900e+09
# 198            -3.963076e+12  ...                        9.726300e+08
# 199            -2.381276e+12  ...                        5.576200e+08
#
#      heat_electrostatic_Electrons  heat_electromagnetic_Electrons  \
# 147                  1.405300e+02                   -7.803900e+00
# 148                  4.835700e+07                   -2.636500e+06
# 149                  5.730100e+07                   -3.011000e+06
# 150                  1.115000e+21                   -5.751100e+19
# 151                  6.163000e+16                   -3.118000e+15
# 152                  1.295500e+12                   -6.301000e+10
# 153                  4.233900e+09                   -2.018500e+08
# 154                  1.578000e+23                   -7.220400e+21
# 155                  3.748500e+02                    4.720400e+00
# 156                           NaN                             NaN
# 157                           NaN                             NaN
# 158                           NaN                             NaN
# 159                           NaN                             NaN
# 160                           NaN                             NaN
# 161                           NaN                             NaN
# 162                           NaN                             NaN
# 163                           NaN                             NaN
# 164                           NaN                             NaN
# 165                           NaN                             NaN
# 166                           NaN                             NaN
# 167                           NaN                             NaN
# 168                           NaN                             NaN
# 169                           NaN                             NaN
# 170                           NaN                             NaN
# 171                           NaN                             NaN
# 172                           NaN                             NaN
# 173                           NaN                             NaN
# 174                           NaN                             NaN
# 175                  1.774200e+23                    2.621900e+21
# 176                  1.456600e+23                    2.177900e+21
# 177                  3.008100e+21                    4.532000e+19
# 178                  2.561100e+21                    3.895400e+19
# 179                  1.043700e+20                    1.593100e+18
# 180                  8.351200e+19                    1.284000e+18
# 181                  6.211700e+18                    9.596400e+16
# 182                  1.454200e+18                    2.249600e+16
# 183                  5.678500e+17                    8.858000e+15
# 184                  1.163000e+17                    1.812600e+15
# 185                  6.768200e+16                    1.061700e+15
# 186                  1.494800e+16                    2.352700e+14
# 187                  1.236500e+16                    1.950200e+14
# 188                  2.833400e+15                    4.478500e+13
# 189                  7.993200e+15                    1.266400e+14
# 190                  6.367500e+14                    1.010100e+13
# 191                  1.947100e+15                    3.090400e+13
# 192                  2.124000e+14                    3.393200e+12
# 193                  5.703500e+14                    9.084800e+12
# 194                  4.685100e+14                    7.450300e+12
# 195                  1.795000e+14                    2.864800e+12
# 196                  1.549900e+14                    2.478000e+12
# 197                  1.569000e+14                    2.488100e+12
# 198                  1.320400e+14                    2.099700e+12
# 199                  7.944600e+13                    1.248800e+12
#
#      particle_electrostatic_Ions  particle_electromagnetic_Ions  \
# 147                -1.256900e+01                  -7.629900e-01
# 148                -4.369900e+06                  -2.620300e+05
# 149                -5.300900e+06                  -3.094600e+05
# 150                -1.044400e+20                  -6.010000e+18
# 151                -5.837800e+15                  -3.317500e+14
# 152                -1.254100e+11                  -6.948400e+09
# 153                -4.144400e+08                  -2.266800e+07
# 154                -1.579500e+22                  -8.421400e+20
# 155                -3.488500e+01                   2.039900e-02
# 156                          NaN                            NaN
# 157                          NaN                            NaN
# 158                          NaN                            NaN
# 159                          NaN                            NaN
# 160                          NaN                            NaN
# 161                          NaN                            NaN
# 162                          NaN                            NaN
# 163                          NaN                            NaN
# 164                          NaN                            NaN
# 165                          NaN                            NaN
# 166                          NaN                            NaN
# 167                          NaN                            NaN
# 168                          NaN                            NaN
# 169                          NaN                            NaN
# 170                          NaN                            NaN
# 171                          NaN                            NaN
# 172                          NaN                            NaN
# 173                          NaN                            NaN
# 174                          NaN                            NaN
# 175                -9.232900e+21                   2.387200e+18
# 176                -7.551200e+21                   1.883700e+18
# 177                -1.558700e+20                   3.909400e+16
# 178                -1.323200e+20                   3.199900e+16
# 179                -5.389000e+18                   1.275100e+15
# 180                -4.299100e+18                   9.767300e+14
# 181                -3.191400e+17                   7.156600e+13
# 182                -7.441500e+16                   1.598000e+13
# 183                -2.900100e+16                   6.163000e+12
# 184                -5.932500e+15                   1.203000e+12
# 185                -3.437700e+15                   6.774700e+11
# 186                -7.606600e+14                   1.493600e+11
# 187                -6.275200e+14                   1.177400e+11
# 188                -1.432100e+14                   2.653200e+10
# 189                -4.041700e+14                   7.243100e+10
# 190                -3.215600e+13                   5.608100e+09
# 191                -9.809700e+13                   1.714300e+10
# 192                -1.066200e+13                   1.769600e+09
# 193                -2.865900e+13                   4.631700e+09
# 194                -2.350000e+13                   3.722200e+09
# 195                -8.983100e+12                   1.409000e+09
# 196                -7.754900e+12                   1.203100e+09
# 197                -7.840500e+12                   1.174900e+09
# 198                -6.594200e+12                   9.726300e+08
# 199                -3.962200e+12                   5.576200e+08
#
#      heat_electrostatic_Ions  heat_electromagnetic_Ions  categorisation  \
# 147             2.025400e+02              -2.644900e+00         Nothing
# 148             6.931500e+07              -9.063000e+05         Nothing
# 149             8.128400e+07              -1.065600e+06         Nothing
# 150             1.573000e+21              -2.064900e+19         Nothing
# 151             8.652200e+16              -1.137300e+15         Nothing
# 152             1.799400e+12              -2.371600e+10         Nothing
# 153             5.849800e+09              -7.720200e+07         Nothing
# 154             2.157900e+23              -2.855600e+21         Nothing
# 155            -1.100200e+01               1.205100e-01         Nothing
# 156                      NaN                        NaN             NaN
# 157                      NaN                        NaN             NaN
# 158                      NaN                        NaN             NaN
# 159                      NaN                        NaN             NaN
# 160                      NaN                        NaN             NaN
# 161                      NaN                        NaN             NaN
# 162                      NaN                        NaN             NaN
# 163                      NaN                        NaN             NaN
# 164                      NaN                        NaN             NaN
# 165                      NaN                        NaN             NaN
# 166                      NaN                        NaN             NaN
# 167                      NaN                        NaN             NaN
# 168                      NaN                        NaN             NaN
# 169                      NaN                        NaN             NaN
# 170                      NaN                        NaN             NaN
# 171                      NaN                        NaN             NaN
# 172                      NaN                        NaN             NaN
# 173                      NaN                        NaN             NaN
# 174                      NaN                        NaN             NaN
# 175            -1.618200e+21               2.627000e+19         Nothing
# 176            -1.323600e+21               2.101400e+19         Nothing
# 177            -2.761200e+19               4.313000e+17         Nothing
# 178            -2.339700e+19               3.579400e+17         Nothing
# 179            -9.518800e+17               1.439600e+16         Nothing
# 180            -7.561500e+17               1.121900e+16         Nothing
# 181            -5.611700e+16               8.249100e+14         Nothing
# 182            -1.290500e+16               1.892900e+14         Nothing
# 183            -5.074500e+15               7.257400e+13         Nothing
# 184            -1.028500e+15               1.458400e+13         Nothing
# 185            -5.954300e+14               8.288700e+12         Nothing
# 186            -1.330700e+14               1.817600e+12         Nothing
# 187            -1.093100e+14               1.464100e+12         Nothing
# 188            -2.483100e+13               3.313200e+11         Nothing
# 189            -6.992700e+13               9.215700e+11         Nothing
# 190            -5.580500e+12               7.183900e+10         Nothing
# 191            -1.707100e+13               2.178100e+11         Nothing
# 192            -1.842600e+12               2.312200e+10         Nothing
# 193            -4.961200e+12               6.130500e+10         Nothing
# 194            -4.060400e+12               4.971300e+10         Nothing
# 195            -1.560800e+12               1.870900e+10         Nothing
# 196            -1.350300e+12               1.599800e+10         Nothing
# 197            -1.360700e+12               1.582400e+10         Nothing
# 198            -1.142200e+12               1.317700e+10         Nothing
# 199            -6.786500e+11               7.726000e+09         Nothing
#
#      avg_kperp_squared  mixing_length
# 147       24297.455933       0.000022
# 148       24522.954534       0.000022
# 149       24977.073145       0.000021
# 150       25205.693125       0.000021
# 151       25435.357977       0.000021
# 152       25897.809030       0.000020
# 153       26130.598578       0.000020
# 154       26599.298978            NaN
# 155       26835.209799            NaN
# 156                NaN            NaN
# 157                NaN            NaN
# 158                NaN            NaN
# 159                NaN            NaN
# 160                NaN            NaN
# 161                NaN            NaN
# 162                NaN            NaN
# 163                NaN            NaN
# 164                NaN            NaN
# 165                NaN            NaN
# 166                NaN            NaN
# 167                NaN            NaN
# 168                NaN            NaN
# 169                NaN            NaN
# 170                NaN            NaN
# 171                NaN            NaN
# 172                NaN            NaN
# 173                NaN            NaN
# 174                NaN            NaN
# 175       33863.643461       0.000018
# 176       34396.920360       0.000018
# 177       34665.119197       0.000018
# 178       35204.645413       0.000018
# 179       35475.972822       0.000018
# 180       36021.748384       0.000018
# 181       36296.200489       0.000018
# 182       36571.690167       0.000018
# 183       37125.802198       0.000018
# 184       37404.416527       0.000018
# 185       37964.773878       0.000018
# 186       38246.516929       0.000018
# 187       38813.123626       0.000018
# 188       39097.991374       0.000018
# 189       39383.896545       0.000018
# 190       39958.835684       0.000018
# 191       40247.869682       0.000018
# 192       40829.058168       0.000018
# 193       41121.216862       0.000018
# 194       41414.412874       0.000018
# 195       42003.933802       0.000018
# 196       42300.258747       0.000018
# 197       42896.029021       0.000018
# 198       43195.478662       0.000018
# 199       43797.498283       0.000018
#
# [53 rows x 28 columns]

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(data_set.df['kymin1'],data_set.df['ratio_iheat_eheat'], 'b',label=f'$\chi_i/ \chi_e$')
plt.plot(data_set.df['kymin1'],data_set.df['ratio_eparticle_eheat'], 'orange', label=f'$D_e/ \chi_e$')
plt.ylabel('growthrate')
plt.legend()

plt.figure()
plt.plot(data_set.df['kymin1'].astype('float'), data_set.df['growthrate'].astype('float'))
plt.xlabel('ky')
plt.ylabel('growthrate')

plt.figure()
plt.plot(data_set.df['kymin1'].astype('float'), data_set.df['mixing_length'].astype('float'))
plt.xlabel('ky')
plt.ylabel('mixing_length')

plt.figure()
plt.plot(data_set.df['kymin1'].astype('float'), data_set.df['run_time'].astype('float'))
plt.vlines(data_set.df['kymin1'].astype('float')[110],0,7000)

print(data_set.df['kymin1'].astype('float')[55])
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_161876/2919505665.py:4: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(data_set.df['kymin1'],data_set.df['ratio_iheat_eheat'], 'b',label=f'$\chi_i/ \chi_e$')
# /tmp/ipykernel_161876/2919505665.py:5: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(data_set.df['kymin1'],data_set.df['ratio_eparticle_eheat'], 'orange', label=f'$D_e/ \chi_e$')
# 0.5871254

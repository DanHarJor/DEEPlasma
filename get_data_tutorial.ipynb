# %%
# %load_ext autoreload
# %autoreload 2

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

parser = GENE_scan_parser(config)

data_set_7D = ScanData('5000s_7p', parser=parser, test_percentage=50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dd95ff60f836> in <module>
# ----> 1 from GENE_ML.gene_ml.dataset.ScanData import ScanData
#       2 from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
#       3 from config import Config
#       4 config = Config()
#       5
#
# /pfs/lustrep4/projappl/project_462000451/DEEPlasma/GENE_ML/gene_ml/dataset/ScanData.py in <module>
#       3 import sys
#       4 import subprocess
# ----> 5 import pandas as pd
#       6 import numpy as np
#       7 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data_set_7D.df, data_set_7D.x_train, data_set_7D.growthrate_train, data_set_7D.x_test, data_set_7D.growthrate_test
# Out:
# (    run_time      omt2      omt1       omn1     shat1       q01     beta1  \
#  0      3.972  55.19910  33.96021  52.008700  1.315692  3.843630  0.001105
#  1      1.705  54.62636  69.78608  51.447960  1.498748  5.092838  0.003788
#  7      1.906  61.25873  56.25225  18.619810  1.736063  5.487717  0.001865
#  10    21.402  33.22105  37.66978  12.453850  1.773974  3.949417  0.003445
#  13     2.036  37.51825  39.12765  59.017660  1.083528  3.687322  0.002222
#  ..       ...       ...       ...        ...       ...       ...       ...
#  239    7.657  66.60476  35.13247  45.245700  3.121494  5.193880  0.001799
#  240   14.749  60.72701  20.90660  40.640050  1.429262  5.057919  0.001787
#  241   11.208  30.88569  16.21406   6.317262  2.238682  5.506229  0.002725
#  244   15.154  27.77436  26.30215  20.327830  3.668582  4.951364  0.003851
#  248    1.546  60.39266  19.62775  54.221810  2.759035  5.126551  0.003441
#
#         kymin1 growthrate frequency
# ...

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

parser = GENE_scan_parser(config)

data_set_3D = ScanData('1000s_3p_uq', parser=parser, test_percentage=50)
# Out:
# /home/djdaniel/DEEPlasma/GENE_ML/gene_ml/parsers/GENEparser.py:376: SyntaxWarning: invalid escape sequence '\d'
#   values = re.findall("(-?\d+\.\d+E[+-]?\d+)", l)#np.array(l.split('  ')"
# /home/djdaniel/anaconda3/envs/gene_ml/lib/python3.12/site-packages/paramiko/pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /home/djdaniel/anaconda3/envs/gene_ml/lib/python3.12/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# ...

# %%
data_set_3D.df, data_set_3D.x_train, data_set_3D.growthrate_train, data_set_3D.x_test, data_set_3D.growthrate_test
# Out:
# (    run_time      omt2      omt1    kymin1 growthrate frequency
#  0        NaN  4.499231  3.205307  0.099908     0.0630    0.0280
#  1        NaN  4.539037  2.281065  0.099908     0.0290    0.0190
#  2        NaN  6.083308  2.551308  0.099908     0.0420   -0.1240
#  3        NaN  5.836209  2.267819  0.099908     0.0400   -0.1250
#  4        NaN  5.275577  2.353216  0.099908     0.0300    0.0180
#  ..       ...       ...       ...       ...        ...       ...
#  92       NaN  4.055202  2.212065  0.099908     0.0270    0.0190
#  93       NaN  5.374778  2.930346  0.099908     0.0510    0.0210
#  94       NaN  6.637011  3.115819  0.099908     0.0550    0.0190
#  95       NaN  5.426347  3.169864  0.099908     0.0600    0.0230
#  96       NaN  4.792574  2.823484  0.099908     0.0490    0.0230
#
#  [491 rows x 6 columns],
#  array([[4.742492  , 2.346237  , 0.09990833],
#         [6.352449  , 3.304948  , 0.09990833],
#         [4.281945  , 3.20599   , 0.09990833],
# ...

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

parser = GENE_scan_parser(config)
remote_save_dir = '/scratch/project_462000451/gene_out/gene_auto/SSG_2p_l4_uq'
data_set = ScanData2('SSG_2p_l4_uq',  parser=parser, config=config, remote_save_dir=remote_save_dir, split_ratio=[0.4,0.1,0.5])
# Out:
# <class 'paramiko.sftp_file.SFTPFile'>
# Initialising dataset
# DEBUG, PATHS /scratch/project_462000451/gene_out/gene_auto/SSG_2p_l4_uq/batch_1/scanfiles0000/scan.log /scratch/project_462000451/gene_out/gene_auto/SSG_2p_l4_uq/batch_1/scanfiles0000/geneerr.log
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto/SSG_2p_l4_uq/batch_1/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line 128: *** entering time loop ***
#
# hstlt, len stat and run_count 0 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 2
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto/SSG_2p_l4_uq/batch_1/scanfiles0000/geneerr.log
# known reasons for gene termination: ['Simulation time limit of.*reached, exiting time loop', 'Linear growth rate is converged, exiting time loop', 'Exit due to reaching the underflow limit']
# ...

# %%
data_set.df
# Out:
#        omt2      omt1 growthrate frequency run_time    termination_reason
# 0  6.700000  3.500000     0.0680    0.0210   48.283  growthrate_converged
# 1  5.350000  2.100000     0.0320   -0.1220   82.210  growthrate_converged
# 2  6.129423  2.800000     0.0450    0.0190  275.932  growthrate_converged
# 0  5.350000  2.800000     0.0460    0.0210   52.860  growthrate_converged
# 1  6.700000  2.800000     0.0520   -0.1270   20.976  growthrate_converged
# 2  5.350000  3.500000     0.0720    0.0270   20.084  growthrate_converged
# 3  4.000000  2.800000     0.0500    0.0260  129.013  growthrate_converged
# 0  4.000000  3.500000     0.0730    0.0340   13.779  growthrate_converged
# 1  6.700000  2.100000     0.0580   -0.1350   27.064  growthrate_converged
# 2  5.350000  3.204145     0.0610    0.0250   27.547  growthrate_converged

# %%
data_set.x_train, data_set.x_val, data_set.x_test
# Out:
# (array([[5.35, 2.1 ],
#         [5.35, 2.8 ],
#         [6.7 , 2.8 ],
#         [4.  , 3.5 ]]),
#  array([[6.129423, 2.8     ]]),
#  array([[6.7     , 3.5     ],
#         [5.35    , 3.5     ],
#         [4.      , 2.8     ],
#         [6.7     , 2.1     ],
#         [5.35    , 3.204145]]))

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

parser = GENE_scan_parser(config)
remote_save_dir = '/scratch/project_462000451/gene_out/gene_auto/code_debug_tester'
data_set = ScanData2('code_debug_tester',  parser=parser, config=config, remote_save_dir=remote_save_dir, split_ratio=[0.4,0.1,0.5])
# Out:
# <class 'paramiko.sftp_file.SFTPFile'>
# Initialising dataset
# DEBUG, PATHS /scratch/project_462000451/gene_out/gene_auto/code_debug_tester/ex-code_debug_tester_batch-0/scanfiles0000/scan.log /scratch/project_462000451/gene_out/gene_auto/code_debug_tester/ex-code_debug_tester_batch-0/scanfiles0000/geneerr.log
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto/code_debug_tester/ex-code_debug_tester_batch-0/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto/code_debug_tester/ex-code_debug_tester_batch-0/scanfiles0000/geneerr.log
# ...

# %%
data_set.df
# Out:
#        omt2      omt1      omn1 growthrate frequency run_time  \
# 0  2.882231  4.499231  2.481900        NaN       NaN    1.966
# 1  3.319788  4.539037  1.750444        NaN       NaN    0.624
# 2  2.726871  6.083308  1.447245        NaN       NaN    0.621
# 3  3.318431  5.836209  0.351876        NaN       NaN    0.620
# 0  3.103663  5.275577  2.882661        NaN       NaN    1.992
# 1  2.186202  6.471158  2.098100        NaN       NaN    0.643
# 2  2.557262  5.960762  0.227311        NaN       NaN    0.651
# 3  2.430981  4.186166  2.593802        NaN       NaN    0.617
#
#   termination_reason
# 0         simtimelim
# 1         simtimelim
# 2         simtimelim
# 3         simtimelim
# 0         simtimelim
# 1         simtimelim
# 2         simtimelim
# 3         simtimelim

# %%
data_set.x_train
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

parser = GENE_scan_parser(config)
remote_save_dir = '/scratch/project_462000451/gene_out/gene_auto/data_gen_tutorial4'
data_gen_tutorial4_data = ScanData2('data_gen_tutorial4',  parser=parser, config=config, remote_save_dir=remote_save_dir, split_ratio=[0.4,0.1,0.5])
# Out:
# <class 'paramiko.sftp_file.SFTPFile'>
# Initialising dataset
# DEBUG, PATHS /scratch/project_462000451/gene_out/gene_auto/data_gen_tutorial4/ex-dgt4_batch-0/scanfiles0000/scan.log /scratch/project_462000451/gene_out/gene_auto/data_gen_tutorial4/ex-dgt4_batch-0/scanfiles0000/geneerr.log
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto/data_gen_tutorial4/ex-dgt4_batch-0/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# There have been 0 unknown reasons for run termination found in /scratch/project_462000451/gene_out/gene_auto/data_gen_tutorial4/ex-dgt4_batch-0/scanfiles0000/geneerr.log
# ...

# %%
data_gen_tutorial4_data.df
# Out:
#        omt2      omt1      omn1 growthrate frequency run_time  \
# 0  3.381341  4.499231  1.386877     8.5470  -25.4860   28.576
# 1  3.116692  4.539037  2.544643     5.6990   -9.4170   31.241
# 2  2.196530  6.083308  2.124313     1.2290   -7.2660  107.051
# 3  2.882231  5.836209  0.328710     3.6090  -36.6460   44.102
# 4  3.319788  5.275577  1.054928     7.7850  -29.4530   24.030
#
#      termination_reason
# 0  growthrate_converged
# 1  growthrate_converged
# 2  growthrate_converged
# 3  growthrate_converged
# 4  growthrate_converged

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

parser = GENE_scan_parser(config)
remote_save_dir = '/scratch/project_462000451/gene_out/gene_auto/FAKE_GENE_UQ'
fake_gene_data_set = ScanData2('FAKE_GENE_UQ',  parser=parser, config=config, remote_save_dir=remote_save_dir, split_ratio=[0.4,0.1,0.5])
# Out:
# <class 'paramiko.sftp_file.SFTPFile'>
# Initialising dataset
# DEBUG, PATHS /scratch/project_462000451/gene_out/gene_auto/FAKE_GENE_UQ/ex-fake_gene_uq_batch-0/scanfiles0000/scan.log /scratch/project_462000451/gene_out/gene_auto/FAKE_GENE_UQ/ex-fake_gene_uq_batch-0/scanfiles0000/geneerr.log
# HIT SIM LIMIT TEST ON FILE: /scratch/project_462000451/gene_out/gene_auto/FAKE_GENE_UQ/ex-fake_gene_uq_batch-0/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line 128: *** entering time loop ***
#
# hstlt, len stat and run_count 0 1
# line 128: *** entering time loop ***
#
# hstlt, len stat and run_count 1 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 4
# line 128: *** entering time loop ***
#
# hstlt, len stat and run_count 4 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 6
# ...

# %% [markdown]
# # Debugging

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config(local=True)

parser = GENE_scan_parser(config)
save_dir = '/home/djdaniel/DEEPlasma/vault/1D_ky'
data_set = ScanData2(config, 'code_debug_tester',  parser=parser, save_dir=save_dir, split_ratio=[0.4,0.1,0.5])
data_set.df
# diff_df = data_set.load_diffusivities('/home/djdaniel/DEEPlasma/vault/1D_ky/ex-1D_ky_batch-0/scanfiles0000')
# Out:
# Initialising dataset
# HIT SIM LIMIT TEST ON FILE: /home/djdaniel/DEEPlasma/vault/1D_ky/ex-1D_ky_batch-0/scanfiles0000/geneerr.log
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 0 0
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 1 1
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 2 2
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 3 3
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 4 4
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 5 5
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 6 6
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 7 7
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 8 8
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 9 9
# line   0: *** entering time loop ***
#
# hstlt, len stat and run_count 10 10
# ...

# %%
data_set.df['fingerprint'].unique()
# Out:
# array(['None'], dtype=object)

# %%
data_set.df[-10:]
# Out:
#       kymin1 growthrate frequency run_time    termination_reason fingerprint  \
# 15  0.913636     2.7720    0.3030   42.085  growthrate_converged        None
# 16  0.923232     2.8060    0.2690   42.153  growthrate_converged        None
# 17  0.932828     2.8400    0.2260   42.854  growthrate_converged        None
# 18  0.942424     2.8720    0.1830   42.547  growthrate_converged        None
# 19  0.952020     2.9040    0.1480   41.698  growthrate_converged        None
# 20  0.961616     2.9350    0.1050   38.406  growthrate_converged        None
# 21  0.971212     2.9640    0.0700   38.142  growthrate_converged        None
# 22  0.980808     2.9940    0.0260   37.505  growthrate_converged        None
# 23  0.990404     3.0230   -0.0100   37.795  growthrate_converged        None
# 24  1.000000     3.0510   -0.0540   37.349  growthrate_converged        None
#
#     ratio_iheat_eheat  ratio_eparticle_eheat
# 15           0.022431              -0.018314
# ...

# %%
diff_df
# Out:
#     particle_diff_1   heat_diff_1  particle_diff_2   heat_diff_2
# 0     -1.125180e+12 -2.928759e+11    -1.125180e+12 -1.549628e+14
# 1     -2.322740e+14 -6.295604e+13    -2.322740e+14 -3.343867e+16
# 2     -8.095615e+19 -2.045241e+19    -8.095615e+19 -1.669207e+21
# 3     -2.030155e+18 -5.116682e+17    -2.030155e+18 -6.152199e+19
# 4     -1.239802e+10 -3.097600e+09    -1.239802e+10 -2.390137e+11
# 5     -1.299904e+07 -3.264570e+06    -1.299904e+07 -2.508325e+08
# 6     -1.391137e+09 -3.388082e+08    -1.391137e+09 -2.591066e+10
# 7     -3.121833e+23 -7.665236e+22    -3.121833e+23 -1.547404e+25
# 8     -6.052070e-04 -1.782348e-04    -6.052070e-04 -4.173001e-02
# 9     -1.028095e+10 -2.544767e+09    -1.028095e+10 -5.564773e+11
# 10    -8.039043e+20 -1.916774e+20    -8.039043e+20 -2.008142e+22
# 11    -6.590102e+12 -1.562408e+12    -6.590102e+12 -1.482472e+14
# 12    -1.206092e+09 -3.122271e+08    -1.206092e+09 -1.295919e+11
# ...

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from config import Config
config = Config()
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
parser = GENE_scan_parser(config)
save_dir = '/scratch/project_462000451/gene_out/out_anna/run_name/'
dataset_anna = ScanData2(name='anna', config=config, parser=parser, save_dir=save_dir,  split_ratio=[0,0,1], categorise=True)#, group_var_list=[('_grp_species_0','omn'),('_grp_species_0','omt'),('_grp_species_0','omt'),('_grp_species_1','temp'),('units','Tref'),('units','nref'),('units','Bref')])
# Out:
# /pfs/lustrep4/projappl/project_462000451/DEEPlasma/GENE_ML/gene_ml/dataset/ScanData.py:749: SyntaxWarning: invalid escape sequence '\c'
#   ax1.plot(df_filtered['kymin1'],df_filtered['ratio_iheat_eheat'], 'b',label=f'$\chi_i/ \chi_e$')
# /pfs/lustrep4/projappl/project_462000451/DEEPlasma/GENE_ML/gene_ml/dataset/ScanData.py:750: SyntaxWarning: invalid escape sequence '\c'
#   ax1.plot(df_filtered['kymin1'],df_filtered['ratio_eparticle_eheat'], 'orange', label=f'$D_e/ \chi_e$')
# /LUMI_TYKKY_A4hLOAk/miniconda/envs/env1/lib/python3.12/site-packages/paramiko/pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# ...

# %%
dataset_anna.df
# Out:
#         kymin1 growthrate  frequency  \
# 0     0.047579     6.7310     0.0250
# 1     0.063439     6.6610     0.3630
# 2     0.095158     6.4590    -0.2100
# 3     0.206175     4.9740     0.4880
# 4     0.301333     0.7430    -0.6130
# 5     0.396491     0.6900    -0.4330
# 6     0.507509     0.4910     0.5790
# 7     0.602666     0.4930     1.0280
# 8     0.697824     0.3800     0.9340
# 9     0.792982     0.5410     0.8480
# 10    0.904000     0.6230     0.7660
# 11    1.000000     0.6510     0.7120
# 12    2.000000     0.0900     0.0460
# 13    4.000000     0.0400     0.2050
# 14    6.000000     0.1950   -25.1520
# 15    8.000000     0.9780   -13.8570
# 16   10.000000     1.5570   -16.8320
# 17   20.000000     7.9870    -9.2430
# 18   30.000000    20.9150   -39.3620
# 19   40.000000    46.6000    -4.1690
# 20   60.000000    62.8860   -59.2920
# 21   80.000000    68.4300    66.2980
# 22  100.000000   124.2750   -21.6580
# 23  150.000000   145.9210  -120.3920
# ...

# %%
dataset_anna.plot_summary()
# Out:
# /pfs/lustrep4/projappl/project_462000451/DEEPlasma/GENE_ML/gene_ml/dataset/ScanData.py:749: SyntaxWarning: invalid escape sequence '\c'
#   ax1.plot(df_filtered['kymin1'],df_filtered['ratio_iheat_eheat'], 'b',label=f'$\chi_i/ \chi_e$')
# /pfs/lustrep4/projappl/project_462000451/DEEPlasma/GENE_ML/gene_ml/dataset/ScanData.py:750: SyntaxWarning: invalid escape sequence '\c'
#   ax1.plot(df_filtered['kymin1'],df_filtered['ratio_eparticle_eheat'], 'orange', label=f'$D_e/ \chi_e$')

# %%
from GENE_ML.gene_ml.dataset.ScanData import ScanData2
from GENE_ML.gene_ml.parsers.GENEparser import GENE_scan_parser
from config import Config
config = Config()

data_dir = 

parser = GENE_scan_parser()
save_dir = '/home/djdaniel/DEEPlasma/vault/1D_ky'
data_set = ScanData2(config, 'code_debug_tester',  parser=parser, save_dir=save_dir, split_ratio=[0.4,0.1,0.5])
data_set.df
# diff_df = data_set.load_diffusivities('/home/djdaniel/DEEPlasma/vault/1D_ky/ex-1D_ky_batch-0/scanfiles0000')

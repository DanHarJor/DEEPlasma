# %%
import matplotlib.pyplot as plt
import numpy as np

values = np.array([0.15, 0.1, 0.5, 0.3, 0.4])
values = values * 5000
labels = ['ETG', 'ITG', 'TEM', 'MTM', 'KBM']

plt.figure(dpi=300)
plt.bar(labels, values, color=['r','b','orange','violet','g'])
plt.xlabel('Micro Instability Modes')
plt.ylabel('Number of Shots with Domination')
plt.title('Hypothetical Mode Identification for 5000 Shot Campaign')
# Out:
# Text(0.5, 1.0, 'Hypothetical Mode Identification for 5000 Shot Campaign')
